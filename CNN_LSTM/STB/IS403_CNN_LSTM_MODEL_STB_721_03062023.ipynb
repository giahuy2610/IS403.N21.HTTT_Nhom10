# %%
#Cài đặt thư viện
import math
import seaborn as sns
import datetime as dt
from datetime import datetime    
sns.set_style("whitegrid")
from pandas.plotting import autocorrelation_plot
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams.update({'font.size': 14})
plt.style.use("ggplot")
import numpy as np 
import pandas as pd 
import os
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error,mean_absolute_error

# %%
#Data mining
def data_mining(data):
  from statsmodels.tsa.seasonal import seasonal_decompose
  result = seasonal_decompose(data, model='additive', period=20)
  #chuyển giá trị trên trục x nghiêng 45 độ
  result.observed.index = result.observed.index.strftime('%d-%m-%Y')
  #Tạo 4 subplots
  fig, ax = plt.subplots(4, 1, figsize=(10, 8))
  #Thực hiện gắn dữ liệu vào từng subplot
  result.observed.plot(ax=ax[0])
  ax[0].set_ylabel('Observed')
  result.trend.plot(ax=ax[1])
  ax[1].set_ylabel('Trend')
  result.seasonal.plot(ax=ax[2])
  ax[2].set_ylabel('Seasonal')
  result.resid.plot(ax=ax[3])
  ax[3].set_ylabel('Residual')
  plt.tight_layout()
  plt.show()

# %%
#Chuẩn hóa dữ liệu
def data_scaling(df):
  scaler=MinMaxScaler()
  df1=scaler.fit_transform(np.array(df).reshape(-1,1))
  return df1, scaler

# %%
#window sliding
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return np.array(dataX),np.array(dataY)

# %%
#Chia dữ liệu
def data_spliting(df1, train_ratio, test_ratio):
  train_size = int(train_ratio * len(df1))
  test_size = int(test_ratio * len(df1))
  val_size = len(df1) - train_size - test_size

  train_data = df1[:train_size]
  test_data = df1[train_size:train_size+test_size]
  val_data = df1[train_size+test_size:]

  return train_data, test_data, val_data

# %%
def cnn_lstm_build_model():
  # For creating model and training
  import tensorflow as tf
  from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, Bidirectional, TimeDistributed
  from tensorflow.keras.layers import MaxPooling1D, Flatten
  from tensorflow.keras.regularizers import L1, L2
  from tensorflow.keras.metrics import Accuracy
  from tensorflow.keras.metrics import RootMeanSquaredError
  import tensorflow.keras.backend as K
  from tensorflow.keras.utils import plot_model

  model = tf.keras.Sequential()

  # Creating the Neural Network model here...
  # CNN layers
  model.add(TimeDistributed(Conv1D(256, kernel_size=3, activation='relu', input_shape=(None, 14, 1))))
  model.add(TimeDistributed(MaxPooling1D(2)))
  model.add(TimeDistributed(Conv1D(128, kernel_size=3, activation='relu')))
  model.add(TimeDistributed(MaxPooling1D(2)))
  model.add(TimeDistributed(Conv1D(64, kernel_size=3, activation='relu')))
  model.add(TimeDistributed(MaxPooling1D(2)))
  model.add(TimeDistributed(Flatten()))
  # model.add(Dense(5, kernel_regularizer=L2(0.01)))

  # LSTM layers
  model.add(Bidirectional(LSTM(100, return_sequences=True)))
  model.add(Dropout(0.5))
  model.add(Bidirectional(LSTM(100, return_sequences=False)))
  model.add(Dropout(0.5))

  def root_mean_squared_error(y_true, y_pred):
          return K.sqrt(K.mean(K.square(y_pred - y_true))) 

  #Final layers
  model.add(Dense(1, activation='linear'))
  model.compile(optimizer='adam', loss=root_mean_squared_error, metrics=['mse', 'mae'])



  return model

# %%
def cnn_lstm_next30days(model, scaler ,val_label_inverse, val_data_df, time_step):
  next30days_index=pd.date_range(val_data_df[-1:].index.date[0],periods = 30 ,freq='D')
  pred_next = np.array([])
  
  val_label_inverse=val_label_inverse[-time_step:].reshape(1,-1).reshape(1,time_step)
  
  for i in range(30):
    y_pred_next = model.predict(val_label_inverse.reshape(1,-1).reshape(1,1,time_step,1))
    val_label_inverse = np.append(val_label_inverse,y_pred_next[0])[1:]
    pred_next = np.append(pred_next,y_pred_next[0])
    
  next30days_predict_inverse = pd.DataFrame(scaler.inverse_transform(pred_next.reshape(-1,1)), index = next30days_index)
  return next30days_predict_inverse

# %%
def cnn_lstm_fit(X_train, y_train,X_test, y_test,X_val, y_val, time_step, scaler, train_data_df, test_data_df, val_data_df, model_name):
  from keras.callbacks import EarlyStopping
  early_stopping = EarlyStopping(monitor='val_loss', patience=40, verbose = 2)
  
  model = cnn_lstm_build_model()
  print("model is built")
  history = model.fit(X_train.reshape(X_train.shape[0],1,time_step,1), np.array(y_train), validation_data=(X_test.reshape(X_test.shape[0],1,time_step,1), np.array(y_test)), epochs=100,batch_size=40, verbose=1, shuffle = True, callbacks=[early_stopping])

  #dự đoán tập test
  test_predict = model.predict(X_test.reshape(X_test.shape[0],1,time_step,1))
  test_predict_inverse = scaler.inverse_transform(test_predict.reshape(-1,1))
  test_label_inverse = scaler.inverse_transform(y_test.reshape(-1,1))
  deviation(test_label_inverse, test_predict_inverse)
  test_predict_inverse = pd.DataFrame(test_predict_inverse, index = test_data_df[(time_step+1):].index)
  test_label_inverse = pd.DataFrame(test_label_inverse, index = test_data_df[(time_step+1):].index)
  visualize(test_label_inverse, test_predict_inverse, model_name)

  #dự đoán tập validate
  val_predict= model.predict(X_val.reshape(X_val.shape[0],1,time_step,1))
  val_predict_inverse =scaler.inverse_transform(val_predict.reshape(-1,1))
  val_label_inverse = scaler.inverse_transform(y_val.reshape(-1,1))
  deviation(val_label_inverse, val_predict_inverse)
  val_predict_inverse = pd.DataFrame(val_predict_inverse, index = val_data_df[(time_step+1):].index)
  val_label_inverse = pd.DataFrame(val_label_inverse, index = val_data_df[(time_step+1):].index)
  
  visualize(val_label_inverse, val_predict_inverse, model_name)



  next30_predict_inverse = cnn_lstm_next30days(model, scaler , y_val, val_data_df, time_step)
  visualize_overview(train_data_df, test_data_df, val_data_df, test_predict_inverse, val_predict_inverse, next30_predict_inverse, model_name)

# %%
def visualize(label ,pred, model_name):
  plt.figure(figsize=(16,9))
  plt.plot(label, label = 'Ground truth')
  plt.plot(pred, label='Predict')
  plt.title(model_name)
  plt.xlabel('Date')
  plt.ylabel('Closing Price')
  plt.legend()
  plt.show()

# %%
#Visualization
def visualize_overview(train_data_df,test_data_df, val_data_df, test_predict_inverse, val_predict_inverse, next30_predict_inverse, model_name):

  plt.figure(figsize=(16,9))
  #train label
  plt.plot(train_data_df, label = 'Train')

  #test label and predict value
  plt.plot(test_data_df, label = 'Test')
  plt.plot(test_predict_inverse, label='Predict')

  #val label and predict value
  plt.plot(val_data_df, label = 'Validate')
  plt.plot(val_predict_inverse, label='ValidatePred')

  #predict next 30 days value
  # plt.plot(next30_predict_inverse, label = 'Predict30days')


  plt.title(model_name)
  plt.xlabel('Date')
  plt.ylabel('Closing Price')
  plt.legend()
  plt.show()

# %%
def mda_cal(actual: np.ndarray, predicted: np.ndarray):
    """ Mean Directional Accuracy """
    return np.mean((np.sign(actual[1:] - actual[:-1]) == np.sign(predicted[1:] - actual[:-1])).astype(int))

# %%
#Đánh giá 
def deviation(test, pred):
  rmse=np.sqrt(mean_squared_error(test,pred))
  print(f"RMSE: {rmse:.2f}")
  mape=mean_absolute_percentage_error(test,pred)
  print(f"MAPE: {mape*100:.2f}%")
  mda = mda_cal(test, pred)
  print(f"MDA: {mda*100:.2f}%")

# %%
#Chọn dataset, tỉ lệ và 
def data_preprocessing(data_src, train_ratio, test_ratio, time_step, model_name):
  df = pd.read_csv(data_src, parse_dates=True,
                       index_col=0).sort_values(by='Date', ascending=True)
  #Xóa dấu , và chuyển về float
  df['Price']=df['Price'].replace(',','',regex=True).astype(float)
  df['Open']=df['Open'].astype(str).str.replace(',','').astype(float)
  df['High']=df['High'].astype(str).str.replace(',','').astype(float)
  df['Low']=df['Low'].astype(str).str.replace(',','').astype(float)
  df['Change %']=df['Change %'].astype(str).str.replace('%','').astype(float)

  #Thực hiện tách chuỗi KL thành 1 chuỗi số float và 1 ký tự cuối sau đó lấy số float đó nhân với 1000 
  #nếu ký tự cuối là K, nếu là M thì nhân với 1000000, nếu không có K hay M thì trả về số float đó
  def convert_value(value):
      if isinstance(value, str):
          if value.endswith('K'):
              return float(value[:-1]) * 1000
          elif value.endswith('M'):
              return float(value[:-1]) * 1000000
          else:
              return float(value)
      else:
          return value

  df['Vol.'] = df['Vol.'].apply(convert_value)

  df = df[['Price']]

  data_mining(df)

  df1, scaler = data_scaling(df)
  
  train_data_df, test_data_df, val_data_df = data_spliting(df,train_ratio, test_ratio)
  train_data, test_data, val_data = data_spliting(df1,train_ratio, test_ratio)

  X_train, y_train = create_dataset(train_data, time_step)
  X_test, y_test = create_dataset(test_data, time_step)
  X_val, y_val = create_dataset(val_data, time_step)

  model =  cnn_lstm_fit(X_train, y_train,X_test, y_test,X_val, y_val, time_step, scaler, train_data_df, test_data_df, val_data_df, model_name)

# %%
data_preprocessing('/content/STB Historical Data.csv', 0.7, 0.2, 40, "CNN_LSTM STB 7-2-1")
# Out:
# model is built
# Epoch 1/100
# 19/19 [==============================] - 14s 200ms/step - loss: 0.2137 - mse: 0.0592 - mae: 0.1653 - val_loss: 0.1502 - val_mse: 0.0268 - val_mae: 0.1306
# Epoch 2/100
# 19/19 [==============================] - 1s 68ms/step - loss: 0.0934 - mse: 0.0089 - mae: 0.0652 - val_loss: 0.1145 - val_mse: 0.0136 - val_mae: 0.1013
# Epoch 3/100
# 19/19 [==============================] - 1s 47ms/step - loss: 0.0859 - mse: 0.0075 - mae: 0.0589 - val_loss: 0.1334 - val_mse: 0.0207 - val_mae: 0.1147
# Epoch 4/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0774 - mse: 0.0062 - mae: 0.0531 - val_loss: 0.1189 - val_mse: 0.0162 - val_mae: 0.1029
# Epoch 5/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0781 - mse: 0.0064 - mae: 0.0524 - val_loss: 0.1605 - val_mse: 0.0300 - val_mae: 0.1424
# Epoch 6/100
# 19/19 [==============================] - 1s 40ms/step - loss: 0.0711 - mse: 0.0053 - mae: 0.0477 - val_loss: 0.1666 - val_mse: 0.0321 - val_mae: 0.1495
# Epoch 7/100
# 19/19 [==============================] - 1s 40ms/step - loss: 0.0739 - mse: 0.0058 - mae: 0.0496 - val_loss: 0.1360 - val_mse: 0.0214 - val_mae: 0.1167
# Epoch 8/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0710 - mse: 0.0053 - mae: 0.0481 - val_loss: 0.1138 - val_mse: 0.0151 - val_mae: 0.0973
# Epoch 9/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0718 - mse: 0.0053 - mae: 0.0481 - val_loss: 0.1404 - val_mse: 0.0227 - val_mae: 0.1224
# Epoch 10/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0674 - mse: 0.0048 - mae: 0.0446 - val_loss: 0.1641 - val_mse: 0.0308 - val_mae: 0.1484
# Epoch 11/100
# 19/19 [==============================] - 1s 40ms/step - loss: 0.0707 - mse: 0.0052 - mae: 0.0466 - val_loss: 0.1005 - val_mse: 0.0117 - val_mae: 0.0860
# Epoch 12/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0591 - mse: 0.0036 - mae: 0.0399 - val_loss: 0.1121 - val_mse: 0.0144 - val_mae: 0.0954
# Epoch 13/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0618 - mse: 0.0040 - mae: 0.0405 - val_loss: 0.1161 - val_mse: 0.0155 - val_mae: 0.0997
# Epoch 14/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0569 - mse: 0.0034 - mae: 0.0381 - val_loss: 0.1265 - val_mse: 0.0181 - val_mae: 0.1108
# Epoch 15/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0605 - mse: 0.0038 - mae: 0.0395 - val_loss: 0.0953 - val_mse: 0.0104 - val_mae: 0.0797
# Epoch 16/100
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0553 - mse: 0.0032 - mae: 0.0365 - val_loss: 0.0934 - val_mse: 0.0099 - val_mae: 0.0778
# Epoch 17/100
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0598 - mse: 0.0038 - mae: 0.0386 - val_loss: 0.0812 - val_mse: 0.0074 - val_mae: 0.0668
# Epoch 18/100
# 19/19 [==============================] - 1s 67ms/step - loss: 0.0576 - mse: 0.0035 - mae: 0.0380 - val_loss: 0.0794 - val_mse: 0.0072 - val_mae: 0.0659
# Epoch 19/100
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0569 - mse: 0.0033 - mae: 0.0376 - val_loss: 0.0971 - val_mse: 0.0107 - val_mae: 0.0814
# Epoch 20/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0566 - mse: 0.0033 - mae: 0.0379 - val_loss: 0.0718 - val_mse: 0.0055 - val_mae: 0.0612
# Epoch 21/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0565 - mse: 0.0033 - mae: 0.0386 - val_loss: 0.0817 - val_mse: 0.0076 - val_mae: 0.0671
# Epoch 22/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0516 - mse: 0.0028 - mae: 0.0338 - val_loss: 0.0725 - val_mse: 0.0058 - val_mae: 0.0610
# Epoch 23/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0586 - mse: 0.0035 - mae: 0.0391 - val_loss: 0.0865 - val_mse: 0.0084 - val_mae: 0.0709
# Epoch 24/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0528 - mse: 0.0029 - mae: 0.0344 - val_loss: 0.0913 - val_mse: 0.0093 - val_mae: 0.0751
# Epoch 25/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0528 - mse: 0.0029 - mae: 0.0348 - val_loss: 0.0773 - val_mse: 0.0068 - val_mae: 0.0630
# Epoch 26/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0496 - mse: 0.0025 - mae: 0.0330 - val_loss: 0.0898 - val_mse: 0.0090 - val_mae: 0.0742
# Epoch 27/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0626 - mse: 0.0041 - mae: 0.0421 - val_loss: 0.0677 - val_mse: 0.0049 - val_mae: 0.0573
# Epoch 28/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0564 - mse: 0.0035 - mae: 0.0376 - val_loss: 0.1036 - val_mse: 0.0118 - val_mae: 0.0881
# Epoch 29/100
# 19/19 [==============================] - 1s 40ms/step - loss: 0.0550 - mse: 0.0031 - mae: 0.0364 - val_loss: 0.0958 - val_mse: 0.0103 - val_mae: 0.0803
# Epoch 30/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0539 - mse: 0.0030 - mae: 0.0363 - val_loss: 0.0669 - val_mse: 0.0050 - val_mae: 0.0553
# Epoch 31/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0532 - mse: 0.0029 - mae: 0.0355 - val_loss: 0.0852 - val_mse: 0.0081 - val_mae: 0.0702
# Epoch 32/100
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0517 - mse: 0.0028 - mae: 0.0343 - val_loss: 0.0704 - val_mse: 0.0056 - val_mae: 0.0573
# Epoch 33/100
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0491 - mse: 0.0025 - mae: 0.0329 - val_loss: 0.0859 - val_mse: 0.0081 - val_mae: 0.0702
# Epoch 34/100
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0477 - mse: 0.0023 - mae: 0.0317 - val_loss: 0.1248 - val_mse: 0.0171 - val_mae: 0.1116
# Epoch 35/100
# 19/19 [==============================] - 1s 41ms/step - loss: 0.0531 - mse: 0.0029 - mae: 0.0353 - val_loss: 0.0905 - val_mse: 0.0090 - val_mae: 0.0753
# Epoch 36/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0493 - mse: 0.0026 - mae: 0.0334 - val_loss: 0.0927 - val_mse: 0.0094 - val_mae: 0.0764
# Epoch 37/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0488 - mse: 0.0025 - mae: 0.0324 - val_loss: 0.0824 - val_mse: 0.0077 - val_mae: 0.0676
# Epoch 38/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0484 - mse: 0.0025 - mae: 0.0315 - val_loss: 0.0977 - val_mse: 0.0109 - val_mae: 0.0833
# Epoch 39/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0495 - mse: 0.0026 - mae: 0.0331 - val_loss: 0.0635 - val_mse: 0.0045 - val_mae: 0.0523
# Epoch 40/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0480 - mse: 0.0024 - mae: 0.0311 - val_loss: 0.0711 - val_mse: 0.0058 - val_mae: 0.0578
# Epoch 41/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0491 - mse: 0.0025 - mae: 0.0329 - val_loss: 0.0795 - val_mse: 0.0071 - val_mae: 0.0653
# Epoch 42/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0493 - mse: 0.0025 - mae: 0.0328 - val_loss: 0.0869 - val_mse: 0.0085 - val_mae: 0.0728
# Epoch 43/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0489 - mse: 0.0025 - mae: 0.0328 - val_loss: 0.0638 - val_mse: 0.0046 - val_mae: 0.0522
# Epoch 44/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0478 - mse: 0.0024 - mae: 0.0323 - val_loss: 0.0675 - val_mse: 0.0051 - val_mae: 0.0552
# Epoch 45/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0487 - mse: 0.0025 - mae: 0.0331 - val_loss: 0.0875 - val_mse: 0.0084 - val_mae: 0.0741
# Epoch 46/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0494 - mse: 0.0026 - mae: 0.0327 - val_loss: 0.0749 - val_mse: 0.0063 - val_mae: 0.0614
# Epoch 47/100
# 19/19 [==============================] - 1s 45ms/step - loss: 0.0477 - mse: 0.0023 - mae: 0.0306 - val_loss: 0.0931 - val_mse: 0.0098 - val_mae: 0.0777
# Epoch 48/100
# 19/19 [==============================] - 1s 51ms/step - loss: 0.0461 - mse: 0.0022 - mae: 0.0309 - val_loss: 0.0865 - val_mse: 0.0082 - val_mae: 0.0719
# Epoch 49/100
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0471 - mse: 0.0023 - mae: 0.0317 - val_loss: 0.0911 - val_mse: 0.0093 - val_mae: 0.0775
# Epoch 50/100
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0474 - mse: 0.0023 - mae: 0.0350 - val_loss: 0.0623 - val_mse: 0.0043 - val_mae: 0.0517
# Epoch 51/100
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0469 - mse: 0.0023 - mae: 0.0320 - val_loss: 0.0631 - val_mse: 0.0045 - val_mae: 0.0523
# Epoch 52/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0470 - mse: 0.0023 - mae: 0.0317 - val_loss: 0.0610 - val_mse: 0.0042 - val_mae: 0.0507
# Epoch 53/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0449 - mse: 0.0021 - mae: 0.0312 - val_loss: 0.0653 - val_mse: 0.0049 - val_mae: 0.0535
# Epoch 54/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0486 - mse: 0.0024 - mae: 0.0315 - val_loss: 0.0828 - val_mse: 0.0077 - val_mae: 0.0700
# Epoch 55/100
# 19/19 [==============================] - 1s 43ms/step - loss: 0.0471 - mse: 0.0023 - mae: 0.0310 - val_loss: 0.0749 - val_mse: 0.0064 - val_mae: 0.0612
# Epoch 56/100
# 19/19 [==============================] - 1s 40ms/step - loss: 0.0436 - mse: 0.0020 - mae: 0.0292 - val_loss: 0.0672 - val_mse: 0.0051 - val_mae: 0.0551
# Epoch 57/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0470 - mse: 0.0023 - mae: 0.0312 - val_loss: 0.0655 - val_mse: 0.0049 - val_mae: 0.0536
# Epoch 58/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0459 - mse: 0.0022 - mae: 0.0315 - val_loss: 0.0774 - val_mse: 0.0067 - val_mae: 0.0636
# Epoch 59/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0443 - mse: 0.0020 - mae: 0.0289 - val_loss: 0.0625 - val_mse: 0.0043 - val_mae: 0.0527
# Epoch 60/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0451 - mse: 0.0021 - mae: 0.0310 - val_loss: 0.0666 - val_mse: 0.0050 - val_mae: 0.0548
# Epoch 61/100
# 19/19 [==============================] - 1s 40ms/step - loss: 0.0478 - mse: 0.0024 - mae: 0.0321 - val_loss: 0.0795 - val_mse: 0.0072 - val_mae: 0.0660
# Epoch 62/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0447 - mse: 0.0021 - mae: 0.0296 - val_loss: 0.0821 - val_mse: 0.0076 - val_mae: 0.0682
# Epoch 63/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0465 - mse: 0.0022 - mae: 0.0312 - val_loss: 0.0981 - val_mse: 0.0107 - val_mae: 0.0831
# Epoch 64/100
# 19/19 [==============================] - 1s 52ms/step - loss: 0.0445 - mse: 0.0021 - mae: 0.0298 - val_loss: 0.0776 - val_mse: 0.0068 - val_mae: 0.0637
# Epoch 65/100
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0433 - mse: 0.0019 - mae: 0.0296 - val_loss: 0.0728 - val_mse: 0.0061 - val_mae: 0.0597
# Epoch 66/100
# 19/19 [==============================] - 1s 69ms/step - loss: 0.0435 - mse: 0.0020 - mae: 0.0302 - val_loss: 0.0609 - val_mse: 0.0041 - val_mae: 0.0510
# Epoch 67/100
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0422 - mse: 0.0018 - mae: 0.0286 - val_loss: 0.0615 - val_mse: 0.0042 - val_mae: 0.0513
# Epoch 68/100
# 19/19 [==============================] - 1s 40ms/step - loss: 0.0440 - mse: 0.0020 - mae: 0.0302 - val_loss: 0.0696 - val_mse: 0.0056 - val_mae: 0.0571
# Epoch 69/100
# 19/19 [==============================] - 1s 37ms/step - loss: 0.0460 - mse: 0.0022 - mae: 0.0304 - val_loss: 0.0711 - val_mse: 0.0057 - val_mae: 0.0586
# Epoch 70/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0451 - mse: 0.0021 - mae: 0.0294 - val_loss: 0.0644 - val_mse: 0.0045 - val_mae: 0.0553
# Epoch 71/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0496 - mse: 0.0025 - mae: 0.0337 - val_loss: 0.0772 - val_mse: 0.0068 - val_mae: 0.0658
# Epoch 72/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0419 - mse: 0.0019 - mae: 0.0291 - val_loss: 0.0669 - val_mse: 0.0051 - val_mae: 0.0553
# Epoch 73/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0428 - mse: 0.0020 - mae: 0.0280 - val_loss: 0.0700 - val_mse: 0.0055 - val_mae: 0.0583
# Epoch 74/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0431 - mse: 0.0019 - mae: 0.0297 - val_loss: 0.0732 - val_mse: 0.0063 - val_mae: 0.0610
# Epoch 75/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0456 - mse: 0.0022 - mae: 0.0304 - val_loss: 0.0876 - val_mse: 0.0086 - val_mae: 0.0757
# Epoch 76/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0520 - mse: 0.0028 - mae: 0.0348 - val_loss: 0.0736 - val_mse: 0.0060 - val_mae: 0.0618
# Epoch 77/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0468 - mse: 0.0023 - mae: 0.0339 - val_loss: 0.0630 - val_mse: 0.0043 - val_mae: 0.0529
# Epoch 78/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0422 - mse: 0.0018 - mae: 0.0298 - val_loss: 0.0692 - val_mse: 0.0054 - val_mae: 0.0564
# Epoch 79/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0415 - mse: 0.0018 - mae: 0.0290 - val_loss: 0.0786 - val_mse: 0.0070 - val_mae: 0.0654
# Epoch 80/100
# 19/19 [==============================] - 1s 56ms/step - loss: 0.0427 - mse: 0.0020 - mae: 0.0294 - val_loss: 0.0627 - val_mse: 0.0044 - val_mae: 0.0517
# Epoch 81/100
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0445 - mse: 0.0021 - mae: 0.0310 - val_loss: 0.0995 - val_mse: 0.0110 - val_mae: 0.0870
# Epoch 82/100
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0458 - mse: 0.0022 - mae: 0.0312 - val_loss: 0.0646 - val_mse: 0.0047 - val_mae: 0.0546
# Epoch 83/100
# 19/19 [==============================] - 1s 36ms/step - loss: 0.0417 - mse: 0.0018 - mae: 0.0280 - val_loss: 0.0698 - val_mse: 0.0056 - val_mae: 0.0584
# Epoch 84/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0410 - mse: 0.0018 - mae: 0.0276 - val_loss: 0.0640 - val_mse: 0.0047 - val_mae: 0.0530
# Epoch 85/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0406 - mse: 0.0017 - mae: 0.0270 - val_loss: 0.0791 - val_mse: 0.0070 - val_mae: 0.0679
# Epoch 86/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0423 - mse: 0.0019 - mae: 0.0278 - val_loss: 0.0759 - val_mse: 0.0067 - val_mae: 0.0647
# Epoch 87/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0409 - mse: 0.0017 - mae: 0.0286 - val_loss: 0.0623 - val_mse: 0.0044 - val_mae: 0.0533
# Epoch 88/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0430 - mse: 0.0019 - mae: 0.0290 - val_loss: 0.0935 - val_mse: 0.0099 - val_mae: 0.0800
# Epoch 89/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0436 - mse: 0.0020 - mae: 0.0289 - val_loss: 0.0763 - val_mse: 0.0067 - val_mae: 0.0652
# Epoch 90/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0444 - mse: 0.0021 - mae: 0.0311 - val_loss: 0.0915 - val_mse: 0.0096 - val_mae: 0.0790
# Epoch 91/100
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0498 - mse: 0.0026 - mae: 0.0349 - val_loss: 0.0642 - val_mse: 0.0047 - val_mae: 0.0532
# Epoch 92/100
# 19/19 [==============================] - 1s 42ms/step - loss: 0.0424 - mse: 0.0019 - mae: 0.0284 - val_loss: 0.0625 - val_mse: 0.0043 - val_mae: 0.0524
# Epoch 93/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0424 - mse: 0.0019 - mae: 0.0308 - val_loss: 0.0703 - val_mse: 0.0057 - val_mae: 0.0590
# Epoch 94/100
# 19/19 [==============================] - 1s 40ms/step - loss: 0.0417 - mse: 0.0018 - mae: 0.0293 - val_loss: 0.0620 - val_mse: 0.0043 - val_mae: 0.0518
# Epoch 95/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0416 - mse: 0.0018 - mae: 0.0278 - val_loss: 0.0855 - val_mse: 0.0086 - val_mae: 0.0733
# Epoch 96/100
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0468 - mse: 0.0024 - mae: 0.0308 - val_loss: 0.0736 - val_mse: 0.0063 - val_mae: 0.0631
# Epoch 97/100
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0443 - mse: 0.0020 - mae: 0.0296 - val_loss: 0.0645 - val_mse: 0.0046 - val_mae: 0.0545
# Epoch 98/100
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0450 - mse: 0.0022 - mae: 0.0299 - val_loss: 0.1026 - val_mse: 0.0118 - val_mae: 0.0900
# Epoch 99/100
# 19/19 [==============================] - 1s 40ms/step - loss: 0.0471 - mse: 0.0023 - mae: 0.0320 - val_loss: 0.0622 - val_mse: 0.0043 - val_mae: 0.0528
# Epoch 100/100
# 19/19 [==============================] - 1s 39ms/step - loss: 0.0449 - mse: 0.0021 - mae: 0.0303 - val_loss: 0.0734 - val_mse: 0.0062 - val_mae: 0.0624
# 6/6 [==============================] - 2s 10ms/step
# RMSE: 2241.12
# MAPE: 8.48%
# MDA: 48.31%
# 3/3 [==============================] - 0s 10ms/step
# RMSE: 1664.91
# MAPE: 5.69%
# MDA: 55.07%
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
