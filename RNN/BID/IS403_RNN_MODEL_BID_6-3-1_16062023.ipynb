# %%
import import_ipynb
#đây là file chứa các hàm cần thiết cho việc dự đoán
#Yêu cầu file rnnlib này phải nằm chung thư mục với file RNN.ipynb
import rnnlib as rnn
# Out:
# importing Jupyter notebook from rnnlib.ipynb

# %%
df_next30days=rnn.RNN_with_bank_and_ratio('BID Historical Data.csv',0.6,0.3,0.1,40,20)
# Out:
# ## BID Historical Data 6-3-1
# Epoch 1/100
# 20/20 [==============================] - 5s 71ms/step - loss: 0.0165 - val_loss: 0.0056
# Epoch 2/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0034 - val_loss: 0.0051
# Epoch 3/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0022 - val_loss: 0.0028
# Epoch 4/100
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 5/100
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0015 - val_loss: 0.0028
# Epoch 6/100
# 20/20 [==============================] - 0s 19ms/step - loss: 0.0013 - val_loss: 0.0022
# Epoch 7/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0012 - val_loss: 0.0023
# Epoch 8/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0010 - val_loss: 0.0019
# Epoch 9/100
# 20/20 [==============================] - 0s 22ms/step - loss: 0.0010 - val_loss: 0.0020
# Epoch 10/100
# ...

# %%
df_next30days.head(30)
# Out:
#             Predict30days
# 2023-06-17   43440.131534
# 2023-06-18   43224.952852
# 2023-06-19   42995.350351
# 2023-06-20   42760.885529
# 2023-06-21   42464.613269
# 2023-06-22   42266.483968
# 2023-06-23   42015.084119
# 2023-06-24   41774.154498
# 2023-06-25   41550.929887
# 2023-06-26   41332.866441
# 2023-06-27   41093.563693
# 2023-06-28   40856.796548
# 2023-06-29   40630.618561
# 2023-06-30   40393.836169
# 2023-07-01   40177.911901
# 2023-07-02   39969.371835
# 2023-07-03   39764.628314
# 2023-07-04   39565.407316
# 2023-07-05   39381.006564
# 2023-07-06   39206.777197
# 2023-07-07   39044.547349
# 2023-07-08   38903.020103
# 2023-07-09   38776.700381
# 2023-07-10   38664.122929
# 2023-07-11   38557.324154
# 2023-07-12   38452.287951
# 2023-07-13   38349.842242
# 2023-07-14   38254.071742
# 2023-07-15   38165.163991
# 2023-07-16   38080.984387
