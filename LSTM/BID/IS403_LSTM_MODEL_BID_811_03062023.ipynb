# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error,mean_absolute_error
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

# %%
#Đọc data
df = pd.read_csv('../BID-Historical-Data.csv',index_col=0,parse_dates=True).sort_values(by='Date',ascending=True)
df = df[['Price']]

# %%
df
# Out:
#                Price
# Date
# 2019-01-02  25,639.0
# 2019-01-03  24,491.0
# 2019-01-04  24,146.6
# 2019-01-07  24,720.6
# 2019-01-08  24,491.0
# ...              ...
# 2023-05-26  43,400.0
# 2023-05-29  43,900.0
# 2023-05-30  43,800.0
# 2023-05-31  44,000.0
# 2023-06-01  43,700.0
#
# [1101 rows x 1 columns]

# %%
#Xóa dấu , và chuyển về float
df['Price']=df['Price'].replace(',','',regex=True).astype(float)

# %%
# 3. Scaler data
scaler=MinMaxScaler()
df=scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
# 4. Chia train test val theo tỉ lệ 8-1-1
train_size = int(0.8 * len(df))
test_size = int(0.1 * len(df))
val_size = len(df) - train_size - test_size

train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
val_data = df[train_size+test_size:]

# %%
# 5. Hàm Create Dataset
#window sliding
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return np.array(dataX),np.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+39 and Y=t+40
time_step = 40
X_train, y_train = create_dataset(train_data, time_step)
X_val, yval = create_dataset(val_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)
X_val = X_val.reshape(X_val.shape[0],X_val.shape[1] , 1)

# %%
# 8. Define LSTM Model
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(40,1)))
model.add(Dropout(0.2))
model.add(LSTM(50,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(50))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1,shuffle=False)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 29s 364ms/step - loss: 0.0228 - val_loss: 0.0123
# Epoch 2/100
# 14/14 [==============================] - 1s 106ms/step - loss: 0.0157 - val_loss: 0.0163
# Epoch 3/100
# 14/14 [==============================] - 1s 96ms/step - loss: 0.0195 - val_loss: 0.0109
# Epoch 4/100
# 14/14 [==============================] - 1s 103ms/step - loss: 0.0131 - val_loss: 0.0113
# Epoch 5/100
# 14/14 [==============================] - 1s 94ms/step - loss: 0.0088 - val_loss: 0.0102
# Epoch 6/100
# 14/14 [==============================] - 1s 95ms/step - loss: 0.0083 - val_loss: 0.0097
# Epoch 7/100
# 14/14 [==============================] - 1s 89ms/step - loss: 0.0091 - val_loss: 0.0088
# Epoch 8/100
# 14/14 [==============================] - 1s 90ms/step - loss: 0.0089 - val_loss: 0.0081
# Epoch 9/100
# 14/14 [==============================] - 1s 90ms/step - loss: 0.0077 - val_loss: 0.0078
# Epoch 10/100
# 14/14 [==============================] - 1s 100ms/step - loss: 0.0080 - val_loss: 0.0075
# Epoch 11/100
# 14/14 [==============================] - 1s 88ms/step - loss: 0.0089 - val_loss: 0.0070
# Epoch 12/100
# 14/14 [==============================] - 1s 93ms/step - loss: 0.0083 - val_loss: 0.0065
# Epoch 13/100
# 14/14 [==============================] - 1s 95ms/step - loss: 0.0069 - val_loss: 0.0062
# Epoch 14/100
# 14/14 [==============================] - 1s 90ms/step - loss: 0.0065 - val_loss: 0.0059
# Epoch 15/100
# 14/14 [==============================] - 1s 88ms/step - loss: 0.0059 - val_loss: 0.0056
# Epoch 16/100
# 14/14 [==============================] - 1s 102ms/step - loss: 0.0059 - val_loss: 0.0056
# Epoch 17/100
# 14/14 [==============================] - 1s 101ms/step - loss: 0.0068 - val_loss: 0.0052
# Epoch 18/100
# 14/14 [==============================] - 2s 109ms/step - loss: 0.0065 - val_loss: 0.0051
# Epoch 19/100
# 14/14 [==============================] - 1s 105ms/step - loss: 0.0060 - val_loss: 0.0050
# Epoch 20/100
# 14/14 [==============================] - 2s 111ms/step - loss: 0.0059 - val_loss: 0.0049
# Epoch 21/100
# 14/14 [==============================] - 1s 106ms/step - loss: 0.0060 - val_loss: 0.0048
# Epoch 22/100
# 14/14 [==============================] - 1s 100ms/step - loss: 0.0054 - val_loss: 0.0046
# Epoch 23/100
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0050 - val_loss: 0.0046
# Epoch 24/100
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 25/100
# 14/14 [==============================] - 2s 108ms/step - loss: 0.0049 - val_loss: 0.0047
# Epoch 26/100
# 14/14 [==============================] - 2s 113ms/step - loss: 0.0049 - val_loss: 0.0046
# Epoch 27/100
# 14/14 [==============================] - 2s 111ms/step - loss: 0.0049 - val_loss: 0.0045
# Epoch 28/100
# 14/14 [==============================] - 1s 106ms/step - loss: 0.0047 - val_loss: 0.0044
# Epoch 29/100
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0048 - val_loss: 0.0043
# Epoch 30/100
# 14/14 [==============================] - 1s 98ms/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 31/100
# 14/14 [==============================] - 1s 97ms/step - loss: 0.0038 - val_loss: 0.0041
# Epoch 32/100
# 14/14 [==============================] - 1s 96ms/step - loss: 0.0037 - val_loss: 0.0043
# Epoch 33/100
# 14/14 [==============================] - 1s 105ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 34/100
# 14/14 [==============================] - 1s 103ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 35/100
# 14/14 [==============================] - 1s 100ms/step - loss: 0.0038 - val_loss: 0.0042
# Epoch 36/100
# 14/14 [==============================] - 1s 106ms/step - loss: 0.0044 - val_loss: 0.0040
# Epoch 37/100
# 14/14 [==============================] - 1s 100ms/step - loss: 0.0040 - val_loss: 0.0044
# Epoch 38/100
# 14/14 [==============================] - 2s 108ms/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 39/100
# 14/14 [==============================] - 1s 84ms/step - loss: 0.0042 - val_loss: 0.0039
# Epoch 40/100
# 14/14 [==============================] - 1s 87ms/step - loss: 0.0037 - val_loss: 0.0039
# Epoch 41/100
# 14/14 [==============================] - 1s 77ms/step - loss: 0.0034 - val_loss: 0.0037
# Epoch 42/100
# 14/14 [==============================] - 1s 84ms/step - loss: 0.0035 - val_loss: 0.0045
# Epoch 43/100
# 14/14 [==============================] - 1s 88ms/step - loss: 0.0041 - val_loss: 0.0037
# Epoch 44/100
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0034 - val_loss: 0.0036
# Epoch 45/100
# 14/14 [==============================] - 1s 65ms/step - loss: 0.0034 - val_loss: 0.0036
# Epoch 46/100
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0034 - val_loss: 0.0037
# Epoch 47/100
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0037 - val_loss: 0.0035
# Epoch 48/100
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0030 - val_loss: 0.0034
# Epoch 49/100
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0030 - val_loss: 0.0033
# Epoch 50/100
# 14/14 [==============================] - 1s 63ms/step - loss: 0.0029 - val_loss: 0.0038
# Epoch 51/100
# 14/14 [==============================] - 1s 63ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 52/100
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0031 - val_loss: 0.0038
# Epoch 53/100
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0033 - val_loss: 0.0037
# Epoch 54/100
# 14/14 [==============================] - 1s 67ms/step - loss: 0.0036 - val_loss: 0.0035
# Epoch 55/100
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 56/100
# 14/14 [==============================] - 1s 64ms/step - loss: 0.0035 - val_loss: 0.0035
# Epoch 57/100
# 14/14 [==============================] - 1s 62ms/step - loss: 0.0035 - val_loss: 0.0036
# Epoch 58/100
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0033 - val_loss: 0.0034
# Epoch 59/100
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0035 - val_loss: 0.0035
# Epoch 60/100
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 61/100
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0031 - val_loss: 0.0037
# Epoch 62/100
# 14/14 [==============================] - 1s 65ms/step - loss: 0.0037 - val_loss: 0.0031
# Epoch 63/100
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0031 - val_loss: 0.0033
# Epoch 64/100
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 65/100
# 14/14 [==============================] - 1s 66ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 66/100
# 14/14 [==============================] - 1s 65ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 67/100
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0028 - val_loss: 0.0031
# Epoch 68/100
# 14/14 [==============================] - 1s 65ms/step - loss: 0.0029 - val_loss: 0.0032
# Epoch 69/100
# 14/14 [==============================] - 1s 62ms/step - loss: 0.0029 - val_loss: 0.0032
# Epoch 70/100
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0027 - val_loss: 0.0034
# Epoch 71/100
# 14/14 [==============================] - 1s 70ms/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 72/100
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0029 - val_loss: 0.0032
# Epoch 73/100
# 14/14 [==============================] - 1s 64ms/step - loss: 0.0033 - val_loss: 0.0030
# Epoch 74/100
# 14/14 [==============================] - 1s 83ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 75/100
# 14/14 [==============================] - 1s 76ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 76/100
# 14/14 [==============================] - 1s 81ms/step - loss: 0.0026 - val_loss: 0.0030
# Epoch 77/100
# 14/14 [==============================] - 1s 77ms/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 78/100
# 14/14 [==============================] - 1s 69ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 79/100
# 14/14 [==============================] - 1s 68ms/step - loss: 0.0026 - val_loss: 0.0028
# Epoch 80/100
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0027 - val_loss: 0.0039
# Epoch 81/100
# 14/14 [==============================] - 1s 63ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 82/100
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 83/100
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 84/100
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0025 - val_loss: 0.0027
# Epoch 85/100
# 14/14 [==============================] - 1s 58ms/step - loss: 0.0025 - val_loss: 0.0027
# Epoch 86/100
# 14/14 [==============================] - 1s 63ms/step - loss: 0.0024 - val_loss: 0.0028
# Epoch 87/100
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0025 - val_loss: 0.0027
# Epoch 88/100
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0024 - val_loss: 0.0027
# Epoch 89/100
# 14/14 [==============================] - 1s 65ms/step - loss: 0.0022 - val_loss: 0.0029
# Epoch 90/100
# 14/14 [==============================] - 1s 66ms/step - loss: 0.0028 - val_loss: 0.0034
# Epoch 91/100
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 92/100
# 14/14 [==============================] - 1s 68ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 93/100
# 14/14 [==============================] - 1s 80ms/step - loss: 0.0024 - val_loss: 0.0027
# Epoch 94/100
# 14/14 [==============================] - 1s 67ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 95/100
# 14/14 [==============================] - 1s 68ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 96/100
# 14/14 [==============================] - 1s 65ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 97/100
# 14/14 [==============================] - 1s 69ms/step - loss: 0.0025 - val_loss: 0.0030
# Epoch 98/100
# 14/14 [==============================] - 1s 64ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 99/100
# 14/14 [==============================] - 1s 62ms/step - loss: 0.0023 - val_loss: 0.0029
# Epoch 100/100
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0028 - val_loss: 0.0026

# %%
# 10. Dự báo dữ liệu test, val
train_predict=model.predict(X_train)
y_pred=model.predict(X_test)
y_pred_val=model.predict(X_val)
# Out:
# 27/27 [==============================] - 1s 11ms/step
# 3/3 [==============================] - 0s 8ms/step
# 3/3 [==============================] - 0s 9ms/step

# %%
# 11. Chuẩn hóa dữ liệu y_pred, y_pred_val
train_predict=scaler.inverse_transform(train_predict)
y_pred=scaler.inverse_transform(y_pred)
y_pred_val=scaler.inverse_transform(y_pred_val)

# %%
ytest=scaler.inverse_transform(ytest.reshape(-1,1))
yval=scaler.inverse_transform(yval.reshape(-1,1))

# %%
#Tính độ đo
valid_rmse = np.sqrt(np.mean((y_pred_val - yval)**2))
test_rmse = np.sqrt(np.mean((y_pred - ytest)**2))
valid_mape = np.mean(np.abs(y_pred_val - yval)/np.abs(yval))  # MAPE
test_mape = np.mean(np.abs(y_pred - ytest)/np.abs(ytest))  # MAPE
valid_mae = mean_absolute_error(y_pred_val,yval) # MAE
test_mae = mean_absolute_error(y_pred,ytest)
print(f"Validation RMSE: {valid_rmse:.2f}")
print(f"Testing RMSE: {test_rmse:.2f}")
print(f"Validation MAPE: {valid_mape* 100:.2f}%")
print(f"Testing MAPE: {test_mape*100:.2f}%")
print(f"Validation MAE: {valid_mae:.2f}")
print(f"Testing MAE: {test_mae:.2f}")
# Out:
# Validation RMSE: 738.69
# Testing RMSE: 1300.86
# Validation MAPE: 1.23%
# Testing MAPE: 2.93%
# Validation MAE: 556.59
# Testing MAE: 1002.65

# %%
df = pd.read_csv('../BID-Historical-Data.csv',index_col=0,parse_dates=True).sort_values(by='Date',ascending=True)

# %%
# 14.Vẽ hình
plt.figure(figsize=(12,6))
plt.ylabel('Closing Price');
plt.xlabel('Date');
plt.title('LSTM BID 8-1-1')
train_index = df[:train_size].index
plt.plot(train_index,scaler.inverse_transform(train_data))
#test
test_index = df[train_size:train_size+test_size].index
plt.plot(test_index,scaler.inverse_transform(test_data))
#test predict
test_predict_index = df[train_size+41:train_size+test_size].index
plt.plot(test_predict_index,(y_pred))
#val
val_index = df[train_size+test_size:train_size+test_size+val_size].index
plt.plot(val_index,scaler.inverse_transform(val_data))
#val predict
val_predict_index = df[train_size+test_size+41:train_size+test_size+val_size].index
plt.plot(val_predict_index,y_pred_val)
#prediect_data_index = pd.RangeIndex(start=len(df)-1, stop=len(df)+29, step=1)
#plt.plot(prediect_data_index,scaler.inverse_transform(lst_output))
plt.legend(['Train','Test','Predict','Validate','ValidatePred'])
plt.show()
