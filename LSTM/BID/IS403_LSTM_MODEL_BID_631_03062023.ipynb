# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error,mean_absolute_error
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

# %%
#Đọc data
df = pd.read_csv('../BID-Historical-Data.csv',index_col=0,parse_dates=True).sort_values(by='Date',ascending=True)
df = df[['Price']]

# %%
df
# Out:
#                 Price
# Date
# 2019-01-02  25,639.00
# 2019-01-03  24,491.00
# 2019-01-04  24,146.60
# 2019-01-07  24,720.60
# 2019-01-08  24,491.00
# ...               ...
# 2023-06-12  43,650.00
# 2023-06-13  44,350.00
# 2023-06-14  44,000.00
# 2023-06-15  43,850.00
# 2023-06-16  43,700.00
#
# [1112 rows x 1 columns]

# %%
#Xóa dấu , và chuyển về float
df['Price']=df['Price'].replace(',','',regex=True).astype(float)

# %%
# 3. Scaler data
scaler=MinMaxScaler()
df=scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
# 4. Chia train test val theo tỉ lệ 6-3-1
train_size = int(0.6 * len(df))
test_size = int(0.3 * len(df))
val_size = len(df) - train_size - test_size

train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
val_data = df[train_size+test_size:]

# %%
# 5. Hàm Create Dataset
#window sliding
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return np.array(dataX),np.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+39 and Y=t+40
time_step = 40
X_train, y_train = create_dataset(train_data, time_step)
X_val, yval = create_dataset(val_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)
X_val = X_val.reshape(X_val.shape[0],X_val.shape[1] , 1)

# %%
# 8. Define LSTM Model
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(40,1)))
model.add(Dropout(0.2))
model.add(LSTM(50,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(50))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1,shuffle=False)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 10s 248ms/step - loss: 0.0213 - val_loss: 0.0232
# Epoch 2/100
# 10/10 [==============================] - 1s 91ms/step - loss: 0.0148 - val_loss: 0.0185
# Epoch 3/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.0132 - val_loss: 0.0272
# Epoch 4/100
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0099 - val_loss: 0.0133
# Epoch 5/100
# 10/10 [==============================] - 1s 75ms/step - loss: 0.0089 - val_loss: 0.0170
# Epoch 6/100
# 10/10 [==============================] - 1s 91ms/step - loss: 0.0082 - val_loss: 0.0139
# Epoch 7/100
# 10/10 [==============================] - 1s 72ms/step - loss: 0.0080 - val_loss: 0.0112
# Epoch 8/100
# 10/10 [==============================] - 1s 118ms/step - loss: 0.0075 - val_loss: 0.0096
# Epoch 9/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0076 - val_loss: 0.0119
# Epoch 10/100
# 10/10 [==============================] - 1s 91ms/step - loss: 0.0064 - val_loss: 0.0109
# Epoch 11/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.0060 - val_loss: 0.0081
# Epoch 12/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.0060 - val_loss: 0.0071
# Epoch 13/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.0054 - val_loss: 0.0070
# Epoch 14/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0058 - val_loss: 0.0066
# Epoch 15/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.0061 - val_loss: 0.0095
# Epoch 16/100
# 10/10 [==============================] - 1s 73ms/step - loss: 0.0052 - val_loss: 0.0117
# Epoch 17/100
# 10/10 [==============================] - 1s 87ms/step - loss: 0.0053 - val_loss: 0.0131
# Epoch 18/100
# 10/10 [==============================] - 1s 85ms/step - loss: 0.0059 - val_loss: 0.0084
# Epoch 19/100
# 10/10 [==============================] - 1s 88ms/step - loss: 0.0051 - val_loss: 0.0070
# Epoch 20/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0045 - val_loss: 0.0079
# Epoch 21/100
# 10/10 [==============================] - 1s 91ms/step - loss: 0.0044 - val_loss: 0.0094
# Epoch 22/100
# 10/10 [==============================] - 1s 121ms/step - loss: 0.0047 - val_loss: 0.0094
# Epoch 23/100
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0048 - val_loss: 0.0077
# Epoch 24/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.0048 - val_loss: 0.0070
# Epoch 25/100
# 10/10 [==============================] - 1s 90ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 26/100
# 10/10 [==============================] - 1s 91ms/step - loss: 0.0043 - val_loss: 0.0085
# Epoch 27/100
# 10/10 [==============================] - 1s 106ms/step - loss: 0.0051 - val_loss: 0.0074
# Epoch 28/100
# 10/10 [==============================] - 1s 102ms/step - loss: 0.0045 - val_loss: 0.0065
# Epoch 29/100
# 10/10 [==============================] - 1s 103ms/step - loss: 0.0043 - val_loss: 0.0068
# Epoch 30/100
# 10/10 [==============================] - 1s 104ms/step - loss: 0.0036 - val_loss: 0.0074
# Epoch 31/100
# 10/10 [==============================] - 1s 107ms/step - loss: 0.0040 - val_loss: 0.0077
# Epoch 32/100
# 10/10 [==============================] - 1s 110ms/step - loss: 0.0038 - val_loss: 0.0081
# Epoch 33/100
# 10/10 [==============================] - 2s 152ms/step - loss: 0.0041 - val_loss: 0.0075
# Epoch 34/100
# 10/10 [==============================] - 1s 148ms/step - loss: 0.0040 - val_loss: 0.0062
# Epoch 35/100
# 10/10 [==============================] - 1s 120ms/step - loss: 0.0036 - val_loss: 0.0067
# Epoch 36/100
# 10/10 [==============================] - 1s 132ms/step - loss: 0.0036 - val_loss: 0.0080
# Epoch 37/100
# 10/10 [==============================] - 1s 110ms/step - loss: 0.0037 - val_loss: 0.0086
# Epoch 38/100
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0037 - val_loss: 0.0092
# Epoch 39/100
# 10/10 [==============================] - 2s 162ms/step - loss: 0.0035 - val_loss: 0.0098
# Epoch 40/100
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0039 - val_loss: 0.0067
# Epoch 41/100
# 10/10 [==============================] - 1s 149ms/step - loss: 0.0038 - val_loss: 0.0050
# Epoch 42/100
# 10/10 [==============================] - 2s 157ms/step - loss: 0.0038 - val_loss: 0.0049
# Epoch 43/100
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0035 - val_loss: 0.0064
# Epoch 44/100
# 10/10 [==============================] - 1s 109ms/step - loss: 0.0033 - val_loss: 0.0059
# Epoch 45/100
# 10/10 [==============================] - 1s 131ms/step - loss: 0.0032 - val_loss: 0.0055
# Epoch 46/100
# 10/10 [==============================] - 1s 119ms/step - loss: 0.0033 - val_loss: 0.0052
# Epoch 47/100
# 10/10 [==============================] - 1s 123ms/step - loss: 0.0030 - val_loss: 0.0060
# Epoch 48/100
# 10/10 [==============================] - 1s 152ms/step - loss: 0.0031 - val_loss: 0.0084
# Epoch 49/100
# 10/10 [==============================] - 1s 121ms/step - loss: 0.0033 - val_loss: 0.0113
# Epoch 50/100
# 10/10 [==============================] - 1s 135ms/step - loss: 0.0034 - val_loss: 0.0055
# Epoch 51/100
# 10/10 [==============================] - 1s 138ms/step - loss: 0.0036 - val_loss: 0.0047
# Epoch 52/100
# 10/10 [==============================] - 1s 129ms/step - loss: 0.0030 - val_loss: 0.0049
# Epoch 53/100
# 10/10 [==============================] - 2s 165ms/step - loss: 0.0030 - val_loss: 0.0046
# Epoch 54/100
# 10/10 [==============================] - 1s 127ms/step - loss: 0.0032 - val_loss: 0.0055
# Epoch 55/100
# 10/10 [==============================] - 1s 128ms/step - loss: 0.0028 - val_loss: 0.0050
# Epoch 56/100
# 10/10 [==============================] - 2s 154ms/step - loss: 0.0031 - val_loss: 0.0056
# Epoch 57/100
# 10/10 [==============================] - 1s 118ms/step - loss: 0.0027 - val_loss: 0.0053
# Epoch 58/100
# 10/10 [==============================] - 1s 127ms/step - loss: 0.0028 - val_loss: 0.0049
# Epoch 59/100
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0027 - val_loss: 0.0050
# Epoch 60/100
# 10/10 [==============================] - 1s 127ms/step - loss: 0.0027 - val_loss: 0.0055
# Epoch 61/100
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0029 - val_loss: 0.0059
# Epoch 62/100
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0030 - val_loss: 0.0046
# Epoch 63/100
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0031 - val_loss: 0.0043
# Epoch 64/100
# 10/10 [==============================] - 1s 126ms/step - loss: 0.0027 - val_loss: 0.0039
# Epoch 65/100
# 10/10 [==============================] - 2s 158ms/step - loss: 0.0027 - val_loss: 0.0047
# Epoch 66/100
# 10/10 [==============================] - 2s 174ms/step - loss: 0.0029 - val_loss: 0.0057
# Epoch 67/100
# 10/10 [==============================] - 1s 149ms/step - loss: 0.0028 - val_loss: 0.0056
# Epoch 68/100
# 10/10 [==============================] - 2s 170ms/step - loss: 0.0030 - val_loss: 0.0058
# Epoch 69/100
# 10/10 [==============================] - 2s 164ms/step - loss: 0.0027 - val_loss: 0.0044
# Epoch 70/100
# 10/10 [==============================] - 2s 155ms/step - loss: 0.0024 - val_loss: 0.0039
# Epoch 71/100
# 10/10 [==============================] - 2s 194ms/step - loss: 0.0026 - val_loss: 0.0052
# Epoch 72/100
# 10/10 [==============================] - 2s 157ms/step - loss: 0.0026 - val_loss: 0.0056
# Epoch 73/100
# 10/10 [==============================] - 2s 158ms/step - loss: 0.0025 - val_loss: 0.0062
# Epoch 74/100
# 10/10 [==============================] - 2s 166ms/step - loss: 0.0026 - val_loss: 0.0068
# Epoch 75/100
# 10/10 [==============================] - 2s 180ms/step - loss: 0.0029 - val_loss: 0.0049
# Epoch 76/100
# 10/10 [==============================] - 2s 162ms/step - loss: 0.0032 - val_loss: 0.0037
# Epoch 77/100
# 10/10 [==============================] - 2s 169ms/step - loss: 0.0027 - val_loss: 0.0034
# Epoch 78/100
# 10/10 [==============================] - 2s 184ms/step - loss: 0.0026 - val_loss: 0.0036
# Epoch 79/100
# 10/10 [==============================] - 2s 164ms/step - loss: 0.0028 - val_loss: 0.0046
# Epoch 80/100
# 10/10 [==============================] - 2s 166ms/step - loss: 0.0026 - val_loss: 0.0032
# Epoch 81/100
# 10/10 [==============================] - 2s 182ms/step - loss: 0.0024 - val_loss: 0.0037
# Epoch 82/100
# 10/10 [==============================] - 2s 176ms/step - loss: 0.0024 - val_loss: 0.0053
# Epoch 83/100
# 10/10 [==============================] - 2s 205ms/step - loss: 0.0026 - val_loss: 0.0067
# Epoch 84/100
# 10/10 [==============================] - 2s 220ms/step - loss: 0.0023 - val_loss: 0.0059
# Epoch 85/100
# 10/10 [==============================] - 2s 231ms/step - loss: 0.0025 - val_loss: 0.0049
# Epoch 86/100
# 10/10 [==============================] - 2s 156ms/step - loss: 0.0026 - val_loss: 0.0047
# Epoch 87/100
# 10/10 [==============================] - 2s 163ms/step - loss: 0.0027 - val_loss: 0.0039
# Epoch 88/100
# 10/10 [==============================] - 2s 158ms/step - loss: 0.0024 - val_loss: 0.0035
# Epoch 89/100
# 10/10 [==============================] - 2s 155ms/step - loss: 0.0023 - val_loss: 0.0054
# Epoch 90/100
# 10/10 [==============================] - 2s 161ms/step - loss: 0.0022 - val_loss: 0.0056
# Epoch 91/100
# 10/10 [==============================] - 2s 163ms/step - loss: 0.0026 - val_loss: 0.0041
# Epoch 92/100
# 10/10 [==============================] - 2s 154ms/step - loss: 0.0021 - val_loss: 0.0040
# Epoch 93/100
# 10/10 [==============================] - 2s 157ms/step - loss: 0.0023 - val_loss: 0.0040
# Epoch 94/100
# 10/10 [==============================] - 2s 156ms/step - loss: 0.0025 - val_loss: 0.0043
# Epoch 95/100
# 10/10 [==============================] - 2s 152ms/step - loss: 0.0021 - val_loss: 0.0057
# Epoch 96/100
# 10/10 [==============================] - 2s 154ms/step - loss: 0.0024 - val_loss: 0.0053
# Epoch 97/100
# 10/10 [==============================] - 1s 153ms/step - loss: 0.0023 - val_loss: 0.0057
# Epoch 98/100
# 10/10 [==============================] - 2s 168ms/step - loss: 0.0025 - val_loss: 0.0045
# Epoch 99/100
# 10/10 [==============================] - 2s 187ms/step - loss: 0.0022 - val_loss: 0.0039
# Epoch 100/100
# 10/10 [==============================] - 2s 158ms/step - loss: 0.0022 - val_loss: 0.0036

# %%
# 10. Dự báo dữ liệu test, val
train_predict=model.predict(X_train)
y_pred=model.predict(X_test)
y_pred_val=model.predict(X_val)
# Out:
# 20/20 [==============================] - 11s 23ms/step
# 10/10 [==============================] - 0s 23ms/step
# 3/3 [==============================] - 0s 19ms/step

# %%
# 11. Chuẩn hóa dữ liệu y_pred, y_pred_val
train_predict=scaler.inverse_transform(train_predict)
y_pred=scaler.inverse_transform(y_pred)
y_pred_val=scaler.inverse_transform(y_pred_val)

# %%
ytest=scaler.inverse_transform(ytest.reshape(-1,1))
yval=scaler.inverse_transform(yval.reshape(-1,1))

# %%
# Tính độ đo MDA trên tập test
test_actual_direction = np.sign(ytest[1:] - ytest[:-1])
test_pred_direction = np.sign(y_pred[1:] - y_pred[:-1])
test_correct = np.where(test_actual_direction == test_pred_direction, 1, 0)
test_mda = np.mean(test_correct)
# Tính độ đo MDA trên tập validation
val_actual_direction = np.sign(yval[1:] - yval[:-1])
val_pred_direction = np.sign(y_pred_val[1:] - y_pred_val[:-1])
val_correct = np.where(val_actual_direction == val_pred_direction, 1, 0)
val_mda = np.mean(val_correct)

# %%
#Tính độ đo
valid_rmse = np.sqrt(np.mean((y_pred_val - yval)**2))
test_rmse = np.sqrt(np.mean((y_pred - ytest)**2))
valid_mape = np.mean(np.abs(y_pred_val - yval)/np.abs(yval))  # MAPE
test_mape = np.mean(np.abs(y_pred - ytest)/np.abs(ytest))  # MAPE
print(f"Validation RMSE: {valid_rmse:.2f}")
print(f"Testing RMSE: {test_rmse:.2f}")
print(f"Validation MAPE: {valid_mape* 100:.2f}%")
print(f"Testing MAPE: {test_mape*100:.2f}%")
print(f"Validation MDA: {test_mda*100:.2f}")
print(f"Testing MDA: {val_mda*100:.2f}")
# Out:
# Validation RMSE: 2768.62
# Testing RMSE: 1529.73
# Validation MAPE: 5.98%
# Testing MAPE: 3.14%
# Validation MDA: 44.67
# Testing MDA: 47.14

# %%
df = pd.read_csv('../BID-Historical-Data.csv',index_col=0,parse_dates=True).sort_values(by='Date',ascending=True)

# %%
# 14.Vẽ hình
plt.figure(figsize=(12,6))
plt.ylabel('Closing Price');
plt.xlabel('Date');
plt.title('LSTM BID 6-3-1')
train_index = df[:train_size].index
plt.plot(train_index,scaler.inverse_transform(train_data))
#test
test_index = df[train_size:train_size+test_size].index
plt.plot(test_index,scaler.inverse_transform(test_data))
#test predict
test_predict_index = df[train_size+41:train_size+test_size].index
plt.plot(test_predict_index,(y_pred))
#val
val_index = df[train_size+test_size:train_size+test_size+val_size].index
plt.plot(val_index,scaler.inverse_transform(val_data))
#val predict
val_predict_index = df[train_size+test_size+41:train_size+test_size+val_size].index
plt.plot(val_predict_index,y_pred_val)
#prediect_data_index = pd.RangeIndex(start=len(df)-1, stop=len(df)+29, step=1)
#plt.plot(prediect_data_index,scaler.inverse_transform(lst_output))
plt.legend(['Train','Test','Predict','Validate','ValidatePred'])
plt.show()
