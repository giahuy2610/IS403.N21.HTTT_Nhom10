# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error,r2_score
from keras.models import Sequential
from keras.layers import Dense, LSTM

# %%
#Đọc data
df = pd.read_csv('VCB-Historical-Data.csv',index_col=0,parse_dates=True).sort_values(by='Date',ascending=True)
df = df['Price']

# %%
#Xóa dấu , và chuyển về float
df=df.replace(',','',regex=True).astype(float)

# %%
# 3. Scaler data
scaler=MinMaxScaler()
df=scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
# 4. Chia train test val theo tỉ lệ 6-3-1
train_size = int(0.6 * len(df))
test_size = int(0.3 * len(df))
val_size = len(df) - train_size - test_size

train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
val_data = df[train_size+test_size:]

# %%
# 5. Hàm Create Dataset
#window sliding
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return np.array(dataX),np.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+39 and Y=t+40
time_step = 40
X_train, y_train = create_dataset(train_data, time_step)
X_val, yval = create_dataset(val_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)
X_val = X_val.reshape(X_val.shape[0],X_val.shape[1] , 1)

# %%
# 8. Define LSTM Model
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(40,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
# Đặt hạt giống
np.random.seed(0)

# %%
# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 7s 200ms/step - loss: 0.0758 - val_loss: 0.0059
# Epoch 2/100
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0139 - val_loss: 0.0166
# Epoch 3/100
# 10/10 [==============================] - 1s 65ms/step - loss: 0.0084 - val_loss: 0.0102
# Epoch 4/100
# 10/10 [==============================] - 1s 59ms/step - loss: 0.0063 - val_loss: 0.0059
# Epoch 5/100
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0048 - val_loss: 0.0079
# Epoch 6/100
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0043 - val_loss: 0.0050
# Epoch 7/100
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0040 - val_loss: 0.0049
# Epoch 8/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0038 - val_loss: 0.0049
# Epoch 9/100
# 10/10 [==============================] - 1s 87ms/step - loss: 0.0037 - val_loss: 0.0048
# Epoch 10/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.0036 - val_loss: 0.0046
# Epoch 11/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0035 - val_loss: 0.0045
# Epoch 12/100
# 10/10 [==============================] - 1s 104ms/step - loss: 0.0034 - val_loss: 0.0044
# Epoch 13/100
# 10/10 [==============================] - 1s 116ms/step - loss: 0.0035 - val_loss: 0.0043
# Epoch 14/100
# 10/10 [==============================] - 1s 121ms/step - loss: 0.0035 - val_loss: 0.0043
# Epoch 15/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.0031 - val_loss: 0.0039
# Epoch 16/100
# 10/10 [==============================] - 1s 90ms/step - loss: 0.0030 - val_loss: 0.0038
# Epoch 17/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0030 - val_loss: 0.0040
# Epoch 18/100
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0030 - val_loss: 0.0035
# Epoch 19/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0029 - val_loss: 0.0038
# Epoch 20/100
# 10/10 [==============================] - 1s 103ms/step - loss: 0.0027 - val_loss: 0.0037
# Epoch 21/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.0027 - val_loss: 0.0034
# Epoch 22/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0026 - val_loss: 0.0033
# Epoch 23/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.0025 - val_loss: 0.0034
# Epoch 24/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0029 - val_loss: 0.0048
# Epoch 25/100
# 10/10 [==============================] - 1s 66ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 26/100
# 10/10 [==============================] - 1s 65ms/step - loss: 0.0024 - val_loss: 0.0029
# Epoch 27/100
# 10/10 [==============================] - 1s 65ms/step - loss: 0.0023 - val_loss: 0.0030
# Epoch 28/100
# 10/10 [==============================] - 1s 68ms/step - loss: 0.0022 - val_loss: 0.0027
# Epoch 29/100
# 10/10 [==============================] - 1s 65ms/step - loss: 0.0022 - val_loss: 0.0028
# Epoch 30/100
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 31/100
# 10/10 [==============================] - 1s 66ms/step - loss: 0.0022 - val_loss: 0.0029
# Epoch 32/100
# 10/10 [==============================] - 1s 64ms/step - loss: 0.0022 - val_loss: 0.0037
# Epoch 33/100
# 10/10 [==============================] - 1s 64ms/step - loss: 0.0020 - val_loss: 0.0025
# Epoch 34/100
# 10/10 [==============================] - 1s 67ms/step - loss: 0.0020 - val_loss: 0.0026
# Epoch 35/100
# 10/10 [==============================] - 1s 64ms/step - loss: 0.0021 - val_loss: 0.0031
# Epoch 36/100
# 10/10 [==============================] - 1s 64ms/step - loss: 0.0024 - val_loss: 0.0060
# Epoch 37/100
# 10/10 [==============================] - 1s 61ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 38/100
# 10/10 [==============================] - 1s 70ms/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 39/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.0018 - val_loss: 0.0024
# Epoch 40/100
# 10/10 [==============================] - 1s 64ms/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 41/100
# 10/10 [==============================] - 1s 63ms/step - loss: 0.0018 - val_loss: 0.0024
# Epoch 42/100
# 10/10 [==============================] - 1s 61ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 43/100
# 10/10 [==============================] - 1s 65ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 44/100
# 10/10 [==============================] - 1s 69ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 45/100
# 10/10 [==============================] - 1s 70ms/step - loss: 0.0015 - val_loss: 0.0025
# Epoch 46/100
# 10/10 [==============================] - 1s 64ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 47/100
# 10/10 [==============================] - 1s 63ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 48/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.0015 - val_loss: 0.0026
# Epoch 49/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 50/100
# 10/10 [==============================] - 1s 70ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 51/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 52/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 53/100
# 10/10 [==============================] - 1s 63ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 54/100
# 10/10 [==============================] - 1s 63ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 55/100
# 10/10 [==============================] - 1s 63ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 56/100
# 10/10 [==============================] - 1s 61ms/step - loss: 0.0013 - val_loss: 0.0029
# Epoch 57/100
# 10/10 [==============================] - 1s 66ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 58/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.0012 - val_loss: 0.0026
# Epoch 59/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.0013 - val_loss: 0.0023
# Epoch 60/100
# 10/10 [==============================] - 1s 66ms/step - loss: 0.0016 - val_loss: 0.0033
# Epoch 61/100
# 10/10 [==============================] - 1s 61ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 62/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 63/100
# 10/10 [==============================] - 1s 68ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 64/100
# 10/10 [==============================] - 1s 63ms/step - loss: 0.0012 - val_loss: 0.0023
# Epoch 65/100
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 66/100
# 10/10 [==============================] - 1s 69ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 67/100
# 10/10 [==============================] - 1s 68ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 68/100
# 10/10 [==============================] - 1s 63ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 69/100
# 10/10 [==============================] - 1s 65ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 70/100
# 10/10 [==============================] - 1s 70ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 71/100
# 10/10 [==============================] - 1s 64ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 72/100
# 10/10 [==============================] - 1s 69ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 73/100
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 74/100
# 10/10 [==============================] - 1s 65ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 75/100
# 10/10 [==============================] - 1s 70ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 76/100
# 10/10 [==============================] - 1s 72ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 77/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.0010 - val_loss: 0.0016
# Epoch 78/100
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 79/100
# 10/10 [==============================] - 1s 64ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 80/100
# 10/10 [==============================] - 1s 66ms/step - loss: 0.0010 - val_loss: 0.0016
# Epoch 81/100
# 10/10 [==============================] - 1s 61ms/step - loss: 0.0011 - val_loss: 0.0021
# Epoch 82/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 83/100
# 10/10 [==============================] - 1s 63ms/step - loss: 9.9927e-04 - val_loss: 0.0015
# Epoch 84/100
# 10/10 [==============================] - 1s 63ms/step - loss: 0.0010 - val_loss: 0.0021
# Epoch 85/100
# 10/10 [==============================] - 1s 68ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 86/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 87/100
# 10/10 [==============================] - 1s 65ms/step - loss: 0.0010 - val_loss: 0.0024
# Epoch 88/100
# 10/10 [==============================] - 1s 68ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 89/100
# 10/10 [==============================] - 1s 64ms/step - loss: 9.8581e-04 - val_loss: 0.0027
# Epoch 90/100
# 10/10 [==============================] - 1s 63ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 91/100
# 10/10 [==============================] - 1s 68ms/step - loss: 8.9449e-04 - val_loss: 0.0012
# Epoch 92/100
# 10/10 [==============================] - 1s 67ms/step - loss: 9.4593e-04 - val_loss: 0.0012
# Epoch 93/100
# 10/10 [==============================] - 1s 64ms/step - loss: 8.9425e-04 - val_loss: 0.0012
# Epoch 94/100
# 10/10 [==============================] - 1s 72ms/step - loss: 8.8415e-04 - val_loss: 0.0012
# Epoch 95/100
# 10/10 [==============================] - 1s 65ms/step - loss: 8.4979e-04 - val_loss: 0.0012
# Epoch 96/100
# 10/10 [==============================] - 1s 62ms/step - loss: 8.8620e-04 - val_loss: 0.0012
# Epoch 97/100
# 10/10 [==============================] - 1s 70ms/step - loss: 9.5435e-04 - val_loss: 0.0013
# Epoch 98/100
# 10/10 [==============================] - 1s 67ms/step - loss: 8.9317e-04 - val_loss: 0.0011
# Epoch 99/100
# 10/10 [==============================] - 1s 61ms/step - loss: 8.2968e-04 - val_loss: 0.0012
# Epoch 100/100
# 10/10 [==============================] - 1s 67ms/step - loss: 9.2754e-04 - val_loss: 0.0015

# %%
# 10. Dự báo dữ liệu test, val
train_predict=model.predict(X_train)
y_pred=model.predict(X_test)
y_pred_val=model.predict(X_val)
# Out:
# 20/20 [==============================] - 2s 12ms/step
# 10/10 [==============================] - 0s 12ms/step
# 3/3 [==============================] - 0s 14ms/step

# %%
# 11. Chuẩn hóa dữ liệu y_pred, y_pred_val
train_predict=scaler.inverse_transform(train_predict)
y_pred=scaler.inverse_transform(y_pred)
y_pred_val=scaler.inverse_transform(y_pred_val)

# %%
ytest=scaler.inverse_transform(ytest.reshape(-1,1))
yval=scaler.inverse_transform(yval.reshape(-1,1))

# %%
# 12. Đánh giá độ chính xác thuật toán bằng RMSE và MAPE
valid_rmse = np.sqrt(np.mean((y_pred_val - yval)**2))
test_rmse = np.sqrt(np.mean((y_pred - ytest)**2))
valid_mape = mean_absolute_percentage_error(y_pred_val,yval)  # MAPE
test_mape = np.mean(np.abs(y_pred - ytest)/np.abs(ytest))  # MAPE
print(f"Validation RMSE: {valid_rmse:.2f}")
print(f"Testing RMSE: {test_rmse:.2f}")
print(f"Validation MAPE: {valid_mape* 100:.2f}%")
print(f"Testing MAPE: {test_mape*100:.2f}%")
# Out:
# Validation RMSE: 2492.13
# Testing RMSE: 2143.02
# Validation MAPE: 2.49%
# Testing MAPE: 2.14%

# %%
df = pd.read_csv('VCB-Historical-Data.csv',index_col=0,parse_dates=True).sort_values(by='Date',ascending=True)

# %%
# 14.Vẽ hình
plt.figure(figsize=(12,6))
train_index = df[:train_size].index
plt.plot(train_index,scaler.inverse_transform(train_data))
#test
test_index = df[train_size:train_size+test_size].index
plt.plot(test_index,scaler.inverse_transform(test_data))
#test predict
test_predict_index = df[train_size+41:train_size+test_size].index
plt.plot(test_predict_index,(y_pred))
#val
val_index = df[train_size+test_size:train_size+test_size+val_size].index
plt.plot(val_index,scaler.inverse_transform(val_data))
#val predict
val_predict_index = df[train_size+test_size+41:train_size+test_size+val_size].index
plt.plot(val_predict_index,y_pred_val)
#prediect_data_index = pd.RangeIndex(start=len(df)-1, stop=len(df)+29, step=1)
#plt.plot(prediect_data_index,scaler.inverse_transform(lst_output))
plt.legend(['Train','Test','Predict','Validate','ValidatePred'])
plt.show()
