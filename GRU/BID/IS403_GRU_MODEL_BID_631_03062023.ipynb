# %%
# 1. Import thư viện cần thiết
from google.colab import drive
drive.mount('/content/drive')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, GRU

from sklearn.metrics import  mean_absolute_percentage_error, mean_absolute_error
# Out:
# Mounted at /content/drive

# %%
# 2. Đọc file csv và gắng index với giá Close
df = pd.read_csv('/content/drive/MyDrive/StockData/BID-Historical-Data.csv',index_col=0,parse_dates=True).sort_values(by='Date',ascending=True)
df['Price']=df['Price'].replace(',','',regex=True).astype(float)

df = df.rename(columns={'Price': 'Close'})
df.head()
# Out:
#               Close      Open      High       Low     Vol. Change %
# Date
# 2019-01-02  25639.0  26,327.8  26,327.8  25,600.7    1.01M   -2.62%
# 2019-01-03  24491.0  25,639.0  25,868.6  24,491.0    1.39M   -4.48%
# 2019-01-04  24146.6  24,108.3  24,452.7  23,572.6    1.83M   -1.41%
# 2019-01-07  24720.6  24,491.0  25,256.3  24,491.0    1.01M    2.38%
# 2019-01-08  24491.0  24,950.2  24,950.2  24,414.4  702.48K   -0.93%

# %%
df1 = df[['Close']]
df1
# Out:
#               Close
# Date
# 2019-01-02  25639.0
# 2019-01-03  24491.0
# 2019-01-04  24146.6
# 2019-01-07  24720.6
# 2019-01-08  24491.0
# ...             ...
# 2023-05-26  43400.0
# 2023-05-29  43900.0
# 2023-05-30  43800.0
# 2023-05-31  44000.0
# 2023-06-01  43700.0
#
# [1101 rows x 1 columns]

# %%
# 3. Scaler data
scaler=MinMaxScaler()
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test val theo tỉ lệ 6-3-1
train_size = int(0.6 * len(df1))
test_size = int(0.3 * len(df1))
val_size = len(df1) - train_size - test_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# %%
# 5. Hàm Create Dataset
#window sliding
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return np.array(dataX),np.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+39 and Y=t+40
time_step = 40
X_train, y_train = create_dataset(train_data, time_step)
X_val, yval = create_dataset(val_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)
X_val = X_val.reshape(X_val.shape[0],X_val.shape[1] , 1)

# %%
# 8. Define GRU Model

model = Sequential()
model.add(GRU(64, input_shape=(time_step, 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=40,verbose=1)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 4s 58ms/step - loss: 0.0746 - val_loss: 0.0310
# Epoch 2/100
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0135 - val_loss: 0.0169
# Epoch 3/100
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0076 - val_loss: 0.0201
# Epoch 4/100
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0053 - val_loss: 0.0081
# Epoch 5/100
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0034 - val_loss: 0.0056
# Epoch 6/100
# 16/16 [==============================] - 1s 83ms/step - loss: 0.0022 - val_loss: 0.0030
# Epoch 7/100
# 16/16 [==============================] - 1s 81ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 8/100
# 16/16 [==============================] - 1s 72ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 9/100
# 16/16 [==============================] - 1s 80ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 10/100
# 16/16 [==============================] - 1s 67ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 11/100
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 12/100
# 16/16 [==============================] - 1s 49ms/step - loss: 0.0015 - val_loss: 0.0024
# Epoch 13/100
# 16/16 [==============================] - 1s 60ms/step - loss: 0.0015 - val_loss: 0.0024
# Epoch 14/100
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 15/100
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 16/100
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 17/100
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 18/100
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 19/100
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0013 - val_loss: 0.0022
# Epoch 20/100
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 21/100
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 22/100
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 23/100
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 24/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 25/100
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 26/100
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0011 - val_loss: 0.0020
# Epoch 27/100
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 28/100
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 29/100
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 30/100
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 31/100
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 32/100
# 16/16 [==============================] - 1s 39ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 33/100
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0010 - val_loss: 0.0017
# Epoch 34/100
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0010 - val_loss: 0.0017
# Epoch 35/100
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 36/100
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0010 - val_loss: 0.0017
# Epoch 37/100
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0010 - val_loss: 0.0016
# Epoch 38/100
# 16/16 [==============================] - 0s 26ms/step - loss: 9.9909e-04 - val_loss: 0.0017
# Epoch 39/100
# 16/16 [==============================] - 0s 25ms/step - loss: 9.9314e-04 - val_loss: 0.0017
# Epoch 40/100
# 16/16 [==============================] - 0s 26ms/step - loss: 9.7383e-04 - val_loss: 0.0017
# Epoch 41/100
# 16/16 [==============================] - 0s 26ms/step - loss: 9.6947e-04 - val_loss: 0.0016
# Epoch 42/100
# 16/16 [==============================] - 0s 26ms/step - loss: 9.8351e-04 - val_loss: 0.0016
# Epoch 43/100
# 16/16 [==============================] - 0s 26ms/step - loss: 9.8709e-04 - val_loss: 0.0016
# Epoch 44/100
# 16/16 [==============================] - 0s 26ms/step - loss: 9.6628e-04 - val_loss: 0.0019
# Epoch 45/100
# 16/16 [==============================] - 0s 25ms/step - loss: 9.5979e-04 - val_loss: 0.0017
# Epoch 46/100
# 16/16 [==============================] - 0s 25ms/step - loss: 9.4913e-04 - val_loss: 0.0017
# Epoch 47/100
# 16/16 [==============================] - 0s 26ms/step - loss: 9.9193e-04 - val_loss: 0.0016
# Epoch 48/100
# 16/16 [==============================] - 0s 26ms/step - loss: 9.4082e-04 - val_loss: 0.0016
# Epoch 49/100
# 16/16 [==============================] - 0s 27ms/step - loss: 9.2276e-04 - val_loss: 0.0017
# Epoch 50/100
# 16/16 [==============================] - 0s 26ms/step - loss: 9.1894e-04 - val_loss: 0.0016
# Epoch 51/100
# 16/16 [==============================] - 0s 26ms/step - loss: 9.1914e-04 - val_loss: 0.0018
# Epoch 52/100
# 16/16 [==============================] - 0s 25ms/step - loss: 9.0805e-04 - val_loss: 0.0017
# Epoch 53/100
# 16/16 [==============================] - 0s 26ms/step - loss: 9.0350e-04 - val_loss: 0.0016
# Epoch 54/100
# 16/16 [==============================] - 0s 25ms/step - loss: 9.0816e-04 - val_loss: 0.0017
# Epoch 55/100
# 16/16 [==============================] - 0s 27ms/step - loss: 8.9230e-04 - val_loss: 0.0018
# Epoch 56/100
# 16/16 [==============================] - 0s 26ms/step - loss: 9.0851e-04 - val_loss: 0.0019
# Epoch 57/100
# 16/16 [==============================] - 0s 24ms/step - loss: 9.1805e-04 - val_loss: 0.0020
# Epoch 58/100
# 16/16 [==============================] - 0s 27ms/step - loss: 9.0211e-04 - val_loss: 0.0018
# Epoch 59/100
# 16/16 [==============================] - 0s 26ms/step - loss: 8.7028e-04 - val_loss: 0.0015
# Epoch 60/100
# 16/16 [==============================] - 0s 31ms/step - loss: 8.7341e-04 - val_loss: 0.0016
# Epoch 61/100
# 16/16 [==============================] - 1s 40ms/step - loss: 8.8776e-04 - val_loss: 0.0016
# Epoch 62/100
# 16/16 [==============================] - 1s 41ms/step - loss: 8.8550e-04 - val_loss: 0.0020
# Epoch 63/100
# 16/16 [==============================] - 1s 40ms/step - loss: 9.4518e-04 - val_loss: 0.0015
# Epoch 64/100
# 16/16 [==============================] - 1s 42ms/step - loss: 8.7387e-04 - val_loss: 0.0016
# Epoch 65/100
# 16/16 [==============================] - 1s 41ms/step - loss: 8.5508e-04 - val_loss: 0.0020
# Epoch 66/100
# 16/16 [==============================] - 1s 40ms/step - loss: 8.9227e-04 - val_loss: 0.0016
# Epoch 67/100
# 16/16 [==============================] - 1s 31ms/step - loss: 8.7593e-04 - val_loss: 0.0016
# Epoch 68/100
# 16/16 [==============================] - 0s 25ms/step - loss: 8.4313e-04 - val_loss: 0.0015
# Epoch 69/100
# 16/16 [==============================] - 0s 26ms/step - loss: 8.5504e-04 - val_loss: 0.0016
# Epoch 70/100
# 16/16 [==============================] - 0s 24ms/step - loss: 8.5636e-04 - val_loss: 0.0019
# Epoch 71/100
# 16/16 [==============================] - 0s 27ms/step - loss: 8.9093e-04 - val_loss: 0.0019
# Epoch 72/100
# 16/16 [==============================] - 0s 25ms/step - loss: 8.6224e-04 - val_loss: 0.0016
# Epoch 73/100
# 16/16 [==============================] - 0s 25ms/step - loss: 8.2349e-04 - val_loss: 0.0015
# Epoch 74/100
# 16/16 [==============================] - 0s 27ms/step - loss: 8.2252e-04 - val_loss: 0.0015
# Epoch 75/100
# 16/16 [==============================] - 0s 25ms/step - loss: 8.3256e-04 - val_loss: 0.0015
# Epoch 76/100
# 16/16 [==============================] - 0s 26ms/step - loss: 8.4372e-04 - val_loss: 0.0015
# Epoch 77/100
# 16/16 [==============================] - 0s 26ms/step - loss: 8.1545e-04 - val_loss: 0.0015
# Epoch 78/100
# 16/16 [==============================] - 0s 25ms/step - loss: 8.3269e-04 - val_loss: 0.0015
# Epoch 79/100
# 16/16 [==============================] - 0s 27ms/step - loss: 8.3068e-04 - val_loss: 0.0015
# Epoch 80/100
# 16/16 [==============================] - 0s 25ms/step - loss: 8.2832e-04 - val_loss: 0.0016
# Epoch 81/100
# 16/16 [==============================] - 0s 26ms/step - loss: 8.0999e-04 - val_loss: 0.0015
# Epoch 82/100
# 16/16 [==============================] - 0s 26ms/step - loss: 8.1112e-04 - val_loss: 0.0015
# Epoch 83/100
# 16/16 [==============================] - 0s 26ms/step - loss: 8.0426e-04 - val_loss: 0.0014
# Epoch 84/100
# 16/16 [==============================] - 0s 26ms/step - loss: 8.3977e-04 - val_loss: 0.0015
# Epoch 85/100
# 16/16 [==============================] - 0s 26ms/step - loss: 8.2052e-04 - val_loss: 0.0015
# Epoch 86/100
# 16/16 [==============================] - 0s 27ms/step - loss: 8.3108e-04 - val_loss: 0.0016
# Epoch 87/100
# 16/16 [==============================] - 0s 26ms/step - loss: 8.2206e-04 - val_loss: 0.0015
# Epoch 88/100
# 16/16 [==============================] - 0s 27ms/step - loss: 7.9105e-04 - val_loss: 0.0014
# Epoch 89/100
# 16/16 [==============================] - 0s 27ms/step - loss: 8.2448e-04 - val_loss: 0.0014
# Epoch 90/100
# 16/16 [==============================] - 0s 26ms/step - loss: 8.4466e-04 - val_loss: 0.0015
# Epoch 91/100
# 16/16 [==============================] - 1s 38ms/step - loss: 7.9959e-04 - val_loss: 0.0015
# Epoch 92/100
# 16/16 [==============================] - 2s 105ms/step - loss: 7.8479e-04 - val_loss: 0.0014
# Epoch 93/100
# 16/16 [==============================] - 2s 96ms/step - loss: 8.0734e-04 - val_loss: 0.0014
# Epoch 94/100
# 16/16 [==============================] - 1s 62ms/step - loss: 7.9342e-04 - val_loss: 0.0015
# Epoch 95/100
# 16/16 [==============================] - 0s 25ms/step - loss: 8.0948e-04 - val_loss: 0.0016
# Epoch 96/100
# 16/16 [==============================] - 0s 27ms/step - loss: 8.6234e-04 - val_loss: 0.0017
# Epoch 97/100
# 16/16 [==============================] - 0s 25ms/step - loss: 8.0659e-04 - val_loss: 0.0015
# Epoch 98/100
# 16/16 [==============================] - 0s 26ms/step - loss: 7.8240e-04 - val_loss: 0.0016
# Epoch 99/100
# 16/16 [==============================] - 0s 26ms/step - loss: 7.9502e-04 - val_loss: 0.0014
# Epoch 100/100
# 16/16 [==============================] - 0s 25ms/step - loss: 8.0931e-04 - val_loss: 0.0014

# %%
# 10. Dự báo dữ liệu test, val
train_predict=model.predict(X_train)
y_pred=model.predict(X_test)
y_pred_val=model.predict(X_val)
# Out:
# 20/20 [==============================] - 1s 6ms/step
# 10/10 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 6ms/step

# %%
# 11. Chuẩn hóa dữ liệu y_pred, y_pred_val
train_predict=scaler.inverse_transform(train_predict)
y_pred=scaler.inverse_transform(y_pred)
y_pred_val=scaler.inverse_transform(y_pred_val)
original_ytest = scaler.inverse_transform(ytest.reshape(-1,1)) 
original_yval = scaler.inverse_transform(yval.reshape(-1,1))

# %%
# 12. Đánh giá độ chính xác thuật toán bằng RMSE
valid_rmse = np.sqrt(np.mean((y_pred_val - original_yval)**2))
test_rmse = np.sqrt(np.mean((y_pred - original_ytest)**2))
print(f"Validation RMSE: {valid_rmse:.2f}")
print(f"Testing RMSE: {test_rmse:.2f}")
# Out:
# Validation RMSE: 691.08
# Testing RMSE: 962.66

# %%
# 13. Đánh giá độ chính xác thuật toán bằng MAE
valid_mae = mean_absolute_error(original_yval, y_pred_val)
test_mae = mean_absolute_error(original_ytest, y_pred)
print(f"Validation MAE: {valid_mae:.2f}")
print(f"Testing MAE: {test_mae:.2f}")
# Out:
# Validation MAE: 496.88
# Testing MAE: 714.09

# %%
# 14. Đánh giá độ chính xác thuật toán bằng MAPE
valid_mape = mean_absolute_percentage_error(original_yval, y_pred_val)
test_mape = mean_absolute_percentage_error(original_ytest,y_pred)
print(f"Validation MAPE: {valid_mape* 100:.2f}%")
print(f"Testing MAPE: {test_mape*100:.2f}%")
# Out:
# Validation MAPE: 1.09%
# Testing MAPE: 1.94%

# %%
# 14.Vẽ hình
plt.figure(figsize=(16,9))
plt.ylabel('Closing Price');
plt.xlabel('Date');
plt.title('GRU BID 6-3-1')
train_index = df[:train_size].index
plt.plot(train_index,scaler.inverse_transform(train_data))
#test
test_index = df[train_size:train_size+test_size].index
plt.plot(test_index,scaler.inverse_transform(test_data))
#test predict
test_predict_index = df[train_size+41:train_size+test_size].index
plt.plot(test_predict_index,(y_pred))
#val
val_index = df[train_size+test_size:train_size+test_size+val_size].index
plt.plot(val_index,scaler.inverse_transform(val_data))
#val predict
val_predict_index = df[train_size+test_size+41:train_size+test_size+val_size].index
plt.plot(val_predict_index,y_pred_val)
#prediect_data_index = pd.RangeIndex(start=len(df)-1, stop=len(df)+29, step=1)
#plt.plot(prediect_data_index,scaler.inverse_transform(lst_output))
plt.legend(['Train','Test','Predict','Validate','ValidatePred'])
plt.show()
