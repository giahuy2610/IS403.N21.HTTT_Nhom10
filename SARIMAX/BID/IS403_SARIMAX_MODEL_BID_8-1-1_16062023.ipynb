# %%
import numpy as np
import import_ipynb
#đây là file chứa các hàm cần thiết cho việc dự đoán
#Yêu cầu file sarimaxlib này phải nằm chung thư mục với file SARIMAX.ipynb
import sarimaxlib as sarimax
# Out:
# importing Jupyter notebook from sarimaxlib.ipynb

# %%
#Lý do có mảng này là do ta chưa xác định được chu kỳ của dữ liệu
#nên ta sẽ thử các chu kỳ từ 2 đến 10 trong auto_arima
SEASONAL_ARR = np.array(range(2, 11))

# %%
#VCB 60/30/10
sarimax.SARIMAX_with_bank_and_ratio('BID Historical Data.csv',0.8,0.1,0.1,SEASONAL_ARR)
# Out:
# ## BID Historical Data.csv 8-1-1
# Seasonal Period:  2
# AIC:  14456.413553439275
# ------------------
# Seasonal Period:  3
# AIC:  14251.962443597813
# ------------------
# Seasonal Period:  4
# AIC:  14251.962443597813
# ------------------
# Seasonal Period:  5
# AIC:  14243.382900403813
# ------------------
# Seasonal Period:  6
# AIC:  14251.962443597813
# ------------------
# Seasonal Period:  7
# AIC:  14251.962443597813
# ------------------
# Seasonal Period:  8
# AIC:  14251.962443597813
# ------------------
# Seasonal Period:  9
# AIC:  14251.962443597813
# ------------------
# Seasonal Period:  10
# AIC:  14251.095981412867
# ------------------
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# d:\Software\Python\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# d:\Software\Python\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                               Price   No. Observations:                  889
# Model:             SARIMAX(2, 1, 2)x(1, 0, [1], 5)   Log Likelihood               -6805.179
# Date:                             Sat, 17 Jun 2023   AIC                          13626.358
# Time:                                     14:45:07   BIC                          13664.670
# Sample:                                          0   HQIC                         13641.003
#                                              - 889
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Price         37.9485      1.223     31.034      0.000      35.552      40.345
# ar.L1          0.0439      0.455      0.096      0.923      -0.849       0.937
# ar.L2          0.6491      0.484      1.340      0.180      -0.301       1.599
# ma.L1         -0.0330      0.464     -0.071      0.943      -0.942       0.876
# ma.L2         -0.6155      0.493     -1.248      0.212      -1.582       0.351
# ar.S.L5        0.5041      0.222      2.270      0.023       0.069       0.939
# ma.S.L5       -0.4154      0.231     -1.794      0.073      -0.869       0.038
# sigma2      2.679e+05   8917.537     30.036      0.000     2.5e+05    2.85e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):               254.46
# Prob(Q):                              0.81   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.62   Skew:                             0.58
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.35
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# Test:
# RMSE: 6077.11
# MAPE: 11.83%
# MDA: 0.50
# ----------------
# Validation:
# RMSE: 14071.03
# MAPE: 31.28%
# MDA: 0.50
