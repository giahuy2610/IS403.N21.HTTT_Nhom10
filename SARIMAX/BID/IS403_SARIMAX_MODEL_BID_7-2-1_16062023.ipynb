# %%
import numpy as np
import import_ipynb
#đây là file chứa các hàm cần thiết cho việc dự đoán
#Yêu cầu file sarimaxlib này phải nằm chung thư mục với file SARIMAX.ipynb
import sarimaxlib as sarimax
# Out:
# importing Jupyter notebook from sarimaxlib.ipynb

# %%
#Lý do có mảng này là do ta chưa xác định được chu kỳ của dữ liệu
#nên ta sẽ thử các chu kỳ từ 2 đến 10 trong auto_arima
SEASONAL_ARR = np.array(range(2, 11))

# %%
#VCB 60/30/10
sarimax.SARIMAX_with_bank_and_ratio('BID Historical Data.csv',0.7,0.2,0.1,SEASONAL_ARR)
# Out:
# ## BID 7-2-1
# Seasonal Period:  2
# AIC:  12576.599686613004
# ------------------
# Seasonal Period:  3
# AIC:  12390.312437029528
# ------------------
# Seasonal Period:  4
# AIC:  12390.312437029528
# ------------------
# Seasonal Period:  5
# AIC:  12386.919333501006
# ------------------
# Seasonal Period:  6
# AIC:  12390.312437029528
# ------------------
# Seasonal Period:  7
# AIC:  12390.312437029528
# ------------------
# Seasonal Period:  8
# AIC:  12390.312437029528
# ------------------
# Seasonal Period:  9
# AIC:  12390.312437029528
# ------------------
# Seasonal Period:  10
# AIC:  12390.312437029528
# ------------------
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                             Price   No. Observations:                  778
# Model:             SARIMAX(0, 1, 0)x(1, 0, 0, 5)   Log Likelihood               -5929.310
# Date:                           Sun, 18 Jun 2023   AIC                          11864.619
# Time:                                   16:18:23   BIC                          11878.586
# Sample:                                        0   HQIC                         11869.992
#                                            - 778
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Price         38.6991      1.211     31.958      0.000      36.326      41.072
# ar.S.L5        0.0660      0.023      2.881      0.004       0.021       0.111
# sigma2      2.491e+05   8267.289     30.136      0.000    2.33e+05    2.65e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.55   Jarque-Bera (JB):               329.87
# Prob(Q):                              0.46   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.14   Skew:                             0.69
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.88
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# Test:
# RMSE: 5302.74
# MAPE: 10.83%
# MDA: 50.77
# ----------------
# Validation:
# RMSE: 15087.70
# MAPE: 33.59%
# MDA: 50.45
