# %%
import numpy as np
import import_ipynb
#đây là file chứa các hàm cần thiết cho việc dự đoán
#Yêu cầu file sarimaxlib này phải nằm chung thư mục với file SARIMAX.ipynb
import sarimaxlib as sarimax
# Out:
# importing Jupyter notebook from sarimaxlib.ipynb

# %%
#Lý do có mảng này là do ta chưa xác định được chu kỳ của dữ liệu
#nên ta sẽ thử các chu kỳ từ 2 đến 10 trong auto_arima
SEASONAL_ARR = np.array(range(2, 11))

# %%
#VCB 60/30/10
sarimax.SARIMAX_with_bank_and_ratio('STB Historical Data.csv',0.6,0.3,0.1,SEASONAL_ARR)
# Out:
# ## STB Historical Data.csv 6-3-1
# Seasonal Period:  2
# AIC:  10052.78684993134
# ------------------
# Seasonal Period:  3
# AIC:  9931.661792816718
# ------------------
# Seasonal Period:  4
# AIC:  9940.577824566419
# ------------------
# Seasonal Period:  5
# AIC:  9940.422786957763
# ------------------
# Seasonal Period:  6
# AIC:  9934.011488455319
# ------------------
# Seasonal Period:  7
# AIC:  9924.5289626846
# ------------------
# Seasonal Period:  8
# AIC:  9940.577824566419
# ------------------
# Seasonal Period:  9
# AIC:  9940.577824566419
# ------------------
# Seasonal Period:  10
# AIC:  9940.56639575919
# ------------------
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# d:\Software\Python\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              Price   No. Observations:                  667
# Model:             SARIMAX(2, 1, 2)x(1, 0, [], 7)   Log Likelihood               -4781.402
# Date:                            Sat, 17 Jun 2023   AIC                           9576.804
# Time:                                    14:44:26   BIC                           9608.313
# Sample:                                         0   HQIC                          9589.012
#                                             - 667
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Price         20.6895      0.808     25.615      0.000      19.106      22.273
# ar.L1         -0.7120      0.019    -36.602      0.000      -0.750      -0.674
# ar.L2         -0.9308      0.018    -53.099      0.000      -0.965      -0.896
# ma.L1          0.7750      0.014     56.966      0.000       0.748       0.802
# ma.L2          0.9784      0.014     70.461      0.000       0.951       1.006
# ar.S.L7       -0.1059      0.025     -4.260      0.000      -0.155      -0.057
# sigma2      1.036e+05   3056.753     33.899      0.000    9.76e+04     1.1e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.31   Jarque-Bera (JB):              1068.62
# Prob(Q):                              0.58   Prob(JB):                         0.00
# Heteroskedasticity (H):              10.51   Skew:                             0.78
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.00
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Test:
# RMSE: 2632.29
# MAPE: 9.62%
# MDA: 0.48
# ----------------
# Validation:
# RMSE: 4305.90
# MAPE: 16.04%
# MDA: 0.39
