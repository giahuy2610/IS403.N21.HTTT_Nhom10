# %%
import numpy as np
import import_ipynb
#đây là file chứa các hàm cần thiết cho việc dự đoán
#Yêu cầu file sarimaxlib này phải nằm chung thư mục với file SARIMAX.ipynb
import sarimaxlib as sarimax
# Out:
# importing Jupyter notebook from sarimaxlib.ipynb

# %%
#Lý do có mảng này là do ta chưa xác định được chu kỳ của dữ liệu
#nên ta sẽ thử các chu kỳ từ 2 đến 10 trong auto_arima
SEASONAL_ARR = np.array(range(2, 11))

# %%
#VCB 60/30/10
sarimax.SARIMAX_with_bank_and_ratio('STB Historical Data.csv',0.8,0.1,0.1,SEASONAL_ARR)
# Out:
# ## STB Historical Data.csv 8-1-1
# Seasonal Period:  2
# AIC:  13778.84275007364
# ------------------
# Seasonal Period:  3
# AIC:  13623.399755799619
# ------------------
# Seasonal Period:  4
# AIC:  13623.399755799619
# ------------------
# Seasonal Period:  5
# AIC:  13620.522712934153
# ------------------
# Seasonal Period:  6
# AIC:  13623.399755799619
# ------------------
# Seasonal Period:  7
# AIC:  13623.399755799619
# ------------------
# Seasonal Period:  8
# AIC:  13623.399755799619
# ------------------
# Seasonal Period:  9
# AIC:  13623.399755799619
# ------------------
# Seasonal Period:  10
# AIC:  13623.399755799619
# ------------------
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                             Price   No. Observations:                  889
# Model:             SARIMAX(0, 1, 0)x(1, 0, 0, 5)   Log Likelihood               -6562.512
# Date:                           Sat, 17 Jun 2023   AIC                          13131.025
# Time:                                   14:43:46   BIC                          13145.391
# Sample:                                        0   HQIC                         13136.516
#                                            - 889
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Price         24.5650      0.805     30.506      0.000      22.987      26.143
# ar.S.L5        0.0286      0.023      1.237      0.216      -0.017       0.074
# sigma2      1.544e+05   4443.099     34.762      0.000    1.46e+05    1.63e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               626.08
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):              10.49   Skew:                             0.67
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.89
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# Test:
# RMSE: 1976.81
# MAPE: 8.05%
# MDA: 0.51
# ----------------
# Validation:
# RMSE: 6155.81
# MAPE: 23.39%
# MDA: 0.39
