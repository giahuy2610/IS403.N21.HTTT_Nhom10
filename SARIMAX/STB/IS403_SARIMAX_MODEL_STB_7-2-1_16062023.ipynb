# %%
import numpy as np
import import_ipynb
#đây là file chứa các hàm cần thiết cho việc dự đoán
#Yêu cầu file sarimaxlib này phải nằm chung thư mục với file SARIMAX.ipynb
import sarimaxlib as sarimax

# %%
#Lý do có mảng này là do ta chưa xác định được chu kỳ của dữ liệu
#nên ta sẽ thử các chu kỳ từ 2 đến 10 trong auto_arima
SEASONAL_ARR = np.array(range(2, 11))

# %%
#VCB 60/30/10
sarimax.SARIMAX_with_bank_and_ratio('STB Historical Data.csv',0.7,0.2,0.1,SEASONAL_ARR)
# Out:
# ## STB Historical Data.csv 7-2-1
# Seasonal Period:  2
# AIC:  11923.566522916957
# ------------------
# Seasonal Period:  3
# AIC:  11797.45473316805
# ------------------
# Seasonal Period:  4
# AIC:  11797.45473316805
# ------------------
# Seasonal Period:  5
# AIC:  11797.45473316805
# ------------------
# Seasonal Period:  6
# AIC:  11797.45473316805
# ------------------
# Seasonal Period:  7
# AIC:  11797.45473316805
# ------------------
# Seasonal Period:  8
# AIC:  11797.45473316805
# ------------------
# Seasonal Period:  9
# AIC:  11797.45473316805
# ------------------
# Seasonal Period:  10
# AIC:  11797.45473316805
# ------------------
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                  778
# Model:               SARIMAX(0, 1, 1)   Log Likelihood               -5710.020
# Date:                Sat, 17 Jun 2023   AIC                          11426.039
# Time:                        14:43:58   BIC                          11440.006
# Sample:                             0   HQIC                         11431.412
#                                 - 778
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Price         23.3265      0.826     28.254      0.000      21.708      24.945
# ma.L1         -0.0397      0.019     -2.115      0.034      -0.076      -0.003
# sigma2      1.421e+05   4042.955     35.139      0.000    1.34e+05     1.5e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):               907.33
# Prob(Q):                              0.94   Prob(JB):                         0.00
# Heteroskedasticity (H):              14.58   Skew:                             0.82
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.04
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# Test:
# RMSE: 4201.35
# MAPE: 17.48%
# MDA: 0.49
# ----------------
# Validation:
# RMSE: 2570.79
# MAPE: 9.03%
# MDA: 0.42
