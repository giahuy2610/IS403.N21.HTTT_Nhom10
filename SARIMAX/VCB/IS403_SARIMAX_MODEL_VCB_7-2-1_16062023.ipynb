# %%
import numpy as np
import import_ipynb
#đây là file chứa các hàm cần thiết cho việc dự đoán
#Yêu cầu file sarimaxlib này phải nằm chung thư mục với file SARIMAX.ipynb
import sarimaxlib as sarimax
# Out:
# importing Jupyter notebook from sarimaxlib.ipynb

# %%
#Lý do có mảng này là do ta chưa xác định được chu kỳ của dữ liệu
#nên ta sẽ thử các chu kỳ từ 2 đến 10 trong auto_arima
SEASONAL_ARR = np.array(range(2, 11))

# %%
#VCB 60/30/10
sarimax.SARIMAX_with_bank_and_ratio('VCB Historical Data.csv',0.7,0.2,0.1,SEASONAL_ARR)
# Out:
# ## VCB 7-2-1
# Seasonal Period:  2
# AIC:  13405.202652250198
# ------------------
# Seasonal Period:  3
# AIC:  13201.549413826757
# ------------------
# Seasonal Period:  4
# AIC:  13203.468992341152
# ------------------
# Seasonal Period:  5
# AIC:  13198.63178705197
# ------------------
# Seasonal Period:  6
# AIC:  13202.378128564782
# ------------------
# Seasonal Period:  7
# AIC:  13203.468992341152
# ------------------
# Seasonal Period:  8
# AIC:  13201.413939168871
# ------------------
# Seasonal Period:  9
# AIC:  13200.760374678537
# ------------------
# Seasonal Period:  10
# AIC:  13200.965379945126
# ------------------
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                               Price   No. Observations:                  778
# Model:             SARIMAX(2, 1, 2)x(0, 0, [1], 5)   Log Likelihood               -6361.249
# Date:                             Sun, 18 Jun 2023   AIC                          12736.497
# Time:                                     16:29:01   BIC                          12769.085
# Sample:                                          0   HQIC                         12749.033
#                                              - 778
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Price         61.9070      1.951     31.733      0.000      58.083      65.731
# ar.L1          0.9770      0.063     15.551      0.000       0.854       1.100
# ar.L2         -0.8869      0.058    -15.205      0.000      -1.001      -0.773
# ma.L1         -0.9912      0.075    -13.293      0.000      -1.137      -0.845
# ma.L2          0.8310      0.071     11.657      0.000       0.691       0.971
# ma.S.L5        0.0576      0.030      1.923      0.054      -0.001       0.116
# sigma2      7.714e+05   2.57e+04     30.023      0.000    7.21e+05    8.22e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.78   Jarque-Bera (JB):               775.14
# Prob(Q):                              0.38   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.18   Skew:                             0.94
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.52
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# Test:
# RMSE: 10550.70
# MAPE: 11.05%
# MDA: 46.98
# ----------------
# Validation:
# RMSE: 31215.40
# MAPE: 33.76%
# MDA: 38.74
