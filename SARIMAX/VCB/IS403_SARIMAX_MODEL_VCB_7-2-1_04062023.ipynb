# %%
import numpy as np
import import_ipynb
#đây là file chứa các hàm cần thiết cho việc dự đoán
#Yêu cầu file sarimaxlib này phải nằm chung thư mục với file SARIMAX.ipynb
import sarimaxlib as sarimax
# Out:
# importing Jupyter notebook from sarimaxlib.ipynb

# %%
#Lý do có mảng này là do ta chưa xác định được chu kỳ của dữ liệu
#nên ta sẽ thử các chu kỳ từ 2 đến 10 trong auto_arima
SEASONAL_ARR = np.array(range(2, 11))

# %%
#VCB 60/30/10
sarimax.SARIMAX_with_bank_and_ratio('VCB Historical Data.csv',0.7,0.2,0.1,SEASONAL_ARR)
# Out:
# ## VCB Historical Data.csv 7-2-1
# Seasonal Period:  2
# AIC:  13253.43482287852
# ------------------
# Seasonal Period:  3
# AIC:  13047.246247795068
# ------------------
# Seasonal Period:  4
# AIC:  13048.953059079493
# ------------------
# Seasonal Period:  5
# AIC:  13044.668735797728
# ------------------
# Seasonal Period:  6
# AIC:  13049.19871066069
# ------------------
# Seasonal Period:  7
# AIC:  13044.965667419536
# ------------------
# Seasonal Period:  8
# AIC:  13044.965667419536
# ------------------
# Seasonal Period:  9
# AIC:  13049.19871066069
# ------------------
# Seasonal Period:  10
# AIC:  13044.965667419536
# ------------------
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# d:\Software\Python\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                             Price   No. Observations:                  770
# Model:             SARIMAX(2, 1, 2)x(0, 0, 2, 5)   Log Likelihood               -6287.174
# Date:                           Sun, 04 Jun 2023   AIC                          12590.347
# Time:                                   15:06:39   BIC                          12627.508
# Sample:                                        0   HQIC                         12604.649
#                                            - 770
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Price         61.2929      1.936     31.661      0.000      57.499      65.087
# ar.L1          0.9493      0.077     12.347      0.000       0.799       1.100
# ar.L2         -0.8633      0.069    -12.524      0.000      -0.998      -0.728
# ma.L1         -0.9630      0.088    -10.983      0.000      -1.135      -0.791
# ma.L2          0.7967      0.081      9.794      0.000       0.637       0.956
# ma.S.L5        0.0488      0.031      1.587      0.113      -0.011       0.109
# ma.S.L10       0.0335      0.036      0.921      0.357      -0.038       0.105
# sigma2      7.514e+05   2.48e+04     30.355      0.000    7.03e+05       8e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.65   Jarque-Bera (JB):               860.25
# Prob(Q):                              0.42   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.01   Skew:                             1.01
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.77
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# Test:
# RMSE: 7051.56
# MAPE: 6.70%
# MDA: 0.47
# ----------------
# Validation:
# RMSE: 23255.97
# MAPE: 25.46%
# MDA: 0.44
