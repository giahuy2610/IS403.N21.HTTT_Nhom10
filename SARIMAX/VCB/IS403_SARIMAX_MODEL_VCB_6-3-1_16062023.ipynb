# %%
import numpy as np
import import_ipynb
#đây là file chứa các hàm cần thiết cho việc dự đoán
#Yêu cầu file sarimaxlib này phải nằm chung thư mục với file SARIMAX.ipynb
import sarimaxlib as sarimax
# Out:
# importing Jupyter notebook from sarimaxlib.ipynb

# %%
#Lý do có mảng này là do ta chưa xác định được chu kỳ của dữ liệu
#nên ta sẽ thử các chu kỳ từ 2 đến 10 trong auto_arima
SEASONAL_ARR = np.array(range(2, 11))

# %%
#VCB 60/30/10
sarimax.SARIMAX_with_bank_and_ratio('VCB Historical Data.csv',0.6,0.3,0.1,SEASONAL_ARR)
# Out:
# ## VCB Historical Data.csv 6-3-1
# Seasonal Period:  2
# AIC:  11472.502514280603
# ------------------
# Seasonal Period:  3
# AIC:  11291.019460616666
# ------------------
# Seasonal Period:  4
# AIC:  11291.019460616666
# ------------------
# Seasonal Period:  5
# AIC:  11287.30930540382
# ------------------
# Seasonal Period:  6
# AIC:  11291.019460616666
# ------------------
# Seasonal Period:  7
# AIC:  11291.019460616666
# ------------------
# Seasonal Period:  8
# AIC:  11291.019460616666
# ------------------
# Seasonal Period:  9
# AIC:  11291.019460616666
# ------------------
# Seasonal Period:  10
# AIC:  11291.019460616666
# ------------------
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                               Price   No. Observations:                  667
# Model:             SARIMAX(2, 1, 2)x(0, 0, [1], 5)   Log Likelihood               -5380.295
# Date:                             Sat, 17 Jun 2023   AIC                          10774.589
# Time:                                     14:45:58   BIC                          10806.098
# Sample:                                          0   HQIC                         10786.797
#                                              - 667
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Price         67.7380      1.952     34.698      0.000      63.912      71.564
# ar.L1          0.8417      0.165      5.111      0.000       0.519       1.165
# ar.L2         -0.6647      0.133     -5.010      0.000      -0.925      -0.405
# ma.L1         -0.9159      0.174     -5.258      0.000      -1.257      -0.574
# ma.L2          0.6098      0.151      4.028      0.000       0.313       0.906
# ma.S.L5        0.0107      0.041      0.261      0.794      -0.070       0.091
# sigma2      6.161e+05   2.41e+04     25.559      0.000    5.69e+05    6.63e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.07   Jarque-Bera (JB):               189.67
# Prob(Q):                              0.79   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.50   Skew:                             0.61
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.31
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# Test:
# RMSE: 10591.88
# MAPE: 11.18%
# MDA: 0.47
# ----------------
# Validation:
# RMSE: 33191.15
# MAPE: 35.95%
# MDA: 0.39
