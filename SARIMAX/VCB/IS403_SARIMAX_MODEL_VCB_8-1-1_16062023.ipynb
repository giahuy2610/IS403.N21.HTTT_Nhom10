# %%
import numpy as np
import import_ipynb
#đây là file chứa các hàm cần thiết cho việc dự đoán
#Yêu cầu file sarimaxlib này phải nằm chung thư mục với file SARIMAX.ipynb
import sarimaxlib as sarimax
# Out:
# importing Jupyter notebook from sarimaxlib.ipynb

# %%
#Lý do có mảng này là do ta chưa xác định được chu kỳ của dữ liệu
#nên ta sẽ thử các chu kỳ từ 2 đến 10 trong auto_arima
SEASONAL_ARR = np.array(range(2, 11))

# %%
#VCB 60/30/10
sarimax.SARIMAX_with_bank_and_ratio('VCB Historical Data.csv',0.8,0.1,0.1,SEASONAL_ARR)
# Out:
# ## VCB 8-1-1
# Seasonal Period:  2
# AIC:  15285.122057146356
# ------------------
# Seasonal Period:  3
# AIC:  15108.198594148338
# ------------------
# Seasonal Period:  4
# AIC:  15108.198594148338
# ------------------
# Seasonal Period:  5
# AIC:  15105.866437225397
# ------------------
# Seasonal Period:  6
# AIC:  15108.198594148338
# ------------------
# Seasonal Period:  7
# AIC:  15108.198594148338
# ------------------
# Seasonal Period:  8
# AIC:  15108.198594148338
# ------------------
# Seasonal Period:  9
# AIC:  15103.585797637328
# ------------------
# Seasonal Period:  10
# AIC:  15108.198594148338
# ------------------
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                               Price   No. Observations:                  889
# Model:             SARIMAX(2, 1, 2)x(1, 0, [1], 9)   Log Likelihood               -7318.387
# Date:                             Sun, 18 Jun 2023   AIC                          14652.775
# Time:                                     16:25:29   BIC                          14691.087
# Sample:                                          0   HQIC                         14667.420
#                                              - 889
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Price         54.5035      1.578     34.544      0.000      51.411      57.596
# ar.L1          0.8375      0.108      7.773      0.000       0.626       1.049
# ar.L2         -0.7747      0.110     -7.056      0.000      -0.990      -0.560
# ma.L1         -0.8397      0.121     -6.915      0.000      -1.078      -0.602
# ma.L2          0.6931      0.126      5.496      0.000       0.446       0.940
# ar.S.L9        0.6458      0.488      1.324      0.185      -0.310       1.602
# ma.S.L9       -0.6734      0.473     -1.423      0.155      -1.601       0.254
# sigma2      8.602e+05   2.68e+04     32.072      0.000    8.08e+05    9.13e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.11   Jarque-Bera (JB):               578.06
# Prob(Q):                              0.74   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.90   Skew:                             0.74
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.66
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# Test:
# RMSE: 9588.25
# MAPE: 10.26%
# MDA: 45.26
# ----------------
# Validation:
# RMSE: 25948.98
# MAPE: 27.95%
# MDA: 38.74
