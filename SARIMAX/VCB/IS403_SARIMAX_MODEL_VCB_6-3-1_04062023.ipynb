# %%
import numpy as np
import import_ipynb
#đây là file chứa các hàm cần thiết cho việc dự đoán
#Yêu cầu file sarimaxlib này phải nằm chung thư mục với file SARIMAX.ipynb
import sarimaxlib as sarimax
# Out:
# importing Jupyter notebook from sarimaxlib.ipynb

# %%
#Lý do có mảng này là do ta chưa xác định được chu kỳ của dữ liệu
#nên ta sẽ thử các chu kỳ từ 2 đến 10 trong auto_arima
SEASONAL_ARR = np.array(range(2, 11))

# %%
#VCB 60/30/10
sarimax.SARIMAX_with_bank_and_ratio('VCB Historical Data.csv',0.6,0.3,0.1,SEASONAL_ARR)
# Out:
# ## VCB Historical Data.csv 6-3-1
# Seasonal Period:  2
# AIC:  11364.639329240243
# ------------------
# Seasonal Period:  3
# AIC:  11177.524339365787
# ------------------
# Seasonal Period:  4
# AIC:  11177.524339365787
# ------------------
# Seasonal Period:  5
# AIC:  11173.5199902003
# ------------------
# Seasonal Period:  6
# AIC:  11177.524339365787
# ------------------
# Seasonal Period:  7
# AIC:  11177.524339365787
# ------------------
# Seasonal Period:  8
# AIC:  11177.524339365787
# ------------------
# Seasonal Period:  9
# AIC:  11177.524339365787
# ------------------
# Seasonal Period:  10
# AIC:  11177.524339365787
# ------------------
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                               Price   No. Observations:                  660
# Model:             SARIMAX(2, 1, 2)x(0, 0, [1], 5)   Log Likelihood               -5327.061
# Date:                             Sun, 04 Jun 2023   AIC                          10668.122
# Time:                                     15:01:21   BIC                          10699.557
# Sample:                                          0   HQIC                         10680.307
#                                              - 660
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Price         67.7699      1.972     34.373      0.000      63.906      71.634
# ar.L1          0.8414      0.167      5.044      0.000       0.514       1.168
# ar.L2         -0.6648      0.134     -4.958      0.000      -0.928      -0.402
# ma.L1         -0.9159      0.176     -5.192      0.000      -1.262      -0.570
# ma.L2          0.6106      0.153      3.991      0.000       0.311       0.910
# ma.S.L5        0.0113      0.041      0.273      0.785      -0.070       0.092
# sigma2      6.224e+05   2.46e+04     25.267      0.000    5.74e+05    6.71e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.07   Jarque-Bera (JB):               179.83
# Prob(Q):                              0.79   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.53   Skew:                             0.60
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.26
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# d:\Software\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# Test:
# RMSE: 9604.00
# MAPE: 10.27%
# MDA: 0.47
# ----------------
# Validation:
# RMSE: 31118.16
# MAPE: 34.34%
# MDA: 0.44
